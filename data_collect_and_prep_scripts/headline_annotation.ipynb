# %%
import openai
import pandas as pd
import numpy as np
import time
import tiktoken
import json
import pickle as pkl
from tiktoken import encoding_for_model

openai.api_key = "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"

#-----------------#
stratified_art_filepath = "S:\\Sync\\University\\2023_MRP_1\\MRP1_WorkDir\\data\\destilled\\r_art_stratified.csv"
stratified_art_df = pd.read_csv(stratified_art_filepath, sep=";")
#-----------------#

def num_tokens_of_prompt(prompt_str, model="gpt-3.5-turbo"):
    """Returns the number of tokens used by a prompt; does not take default constant tokens into account"""
    try:
        encoding = tiktoken.encoding_for_model(model)
    except KeyError:
        encoding = tiktoken.get_encoding("cl100k_base")
    num_tokens = len(encoding.encode(prompt_str))
    return num_tokens


def num_tokens_of_chat_messages(messages, model="gpt-3.5-turbo-0301"):
    """Returns the number of tokens used by a list of messages."""
    try:
        encoding = tiktoken.encoding_for_model(model)
    except KeyError:
        encoding = tiktoken.get_encoding("cl100k_base")
    if model == "gpt-3.5-turbo-0301":  # note: future models may deviate from this
        num_tokens = 0
        for message in messages:
            num_tokens += 4  # every message follows <im_start>{role/name}\n{content}<im_end>\n
            for key, value in message.items():
                num_tokens += len(encoding.encode(value))
                if key == "name":  # if there's a name, the role is omitted
                    num_tokens += -1  # role is always required and always 1 token
        num_tokens += 2  # every reply is primed with <im_start>assistant
        return num_tokens

# %%
def gpt_prepare_batched_prompt(articles_df,  annotation_classes, include_annot_criteria,annotation_batch_size=4, sample_separator=" \n\n ", verbose=-1):
    
    assert type(annotation_classes) == dict, "annotation_classes must be givn as a dictionary of the form {annotation_feature: [annotation_class1, annotation_class2, ...]}"
    
    chat_prompts = {annot_feat: [] for annot_feat in annotation_classes.keys()}
    
    # Import instructions, annotation criteria from JSON file and get the comment ids
    annotat_feature_intro_prompts = {}
    for annot_feat, annot_feat_classes in annotation_classes.items():
        assert type(annot_feat_classes) == list, "annotation_classes must be givn as a dictionary of the form {annotation_feature: [annotation_class1, annotation_class2, ...]}"   
        annotat_feature_intro_prompts[annot_feat] = """Label {} towards quantum science & technology strictly only with {}. The annotation criteria for each {} class are as follows: \n""".format(annot_feat, ", ".join(annot_feat_classes[:-1]) + " or " + annot_feat_classes[-1], annot_feat)
    annotation_criteria = json.load(open("./headline_annotation_criteria.json", "r"))
    assert set(annotation_classes.keys()) == set(annotation_criteria.keys()), "annotation_classes and annotation_criteria must have the same keys"
    
    
    # Split the headlines into batches with maximum size of annotation_batch_size
    #First collect all full batches
    
    art_ids = articles_df["article_id"].values
    batches = []
    num_batches = len(articles_df) // annotation_batch_size
    batches.extend([art_ids[i * annotation_batch_size : (i + 1) * annotation_batch_size] for i in range(num_batches)])
    #Then collect the last batch if it is not full
    if len(articles_df) % annotation_batch_size != 0:
        batches.append(art_ids[num_batches * annotation_batch_size:])

    art_info_batched_collection = []
    
    print("Prepared ", len(batches), " batches of size ", [len(batch) for batch in batches], " each")
    
    for b_i, batch in enumerate(batches):
        # Engineer batch prompt as: Instruction base prompt + Annotation criteria + Samples to annotate
        batch_size = len(batch)
        
        batch_art_headlines = [articles_df[articles_df["article_id"] == c_art_id]["headline"].values[0] for c_art_id in batch]
        batch_art_inputs = [" <#{}#> ".format(art_batch_idx+1) + art_headline for art_batch_idx, art_headline in enumerate(batch_art_headlines)]
        
        # ----- Store comment metadata, body and article info for later reference -------
        batch_info = []
        
        
        for art_num_in_batch, (art_id, art_headline) in enumerate(zip(batch, batch_art_headlines)):
            batch_info.append({"article_id": art_id, 
                                "batch_#": b_i+1,
                               "article_#_in_batch": art_num_in_batch+1,
                               "headline": art_headline,
                               })
        
        art_info_batched_collection.append(batch_info)
        # ----<---------------------------------------------------------------------------
        
        samples_intro_prompt = """Here are the article headlines for annotation: \n"""

        for annot_feat in annotation_classes.keys():
            print("Preparing batch ", b_i+1, " of ", len(batches), " for annotation feature ", annot_feat)
            
            if include_annot_criteria:
                                               
                context_prompt_1 = {annot_feat : """You are an annotator. Your task is to annotate a given set of article headlines on their {} towards quantum science & technology. The headlines correspond to news articles or press releases, which were referenced in science or technology related subreddits on Reddit. Your goal is to strictly follow the given set of annotation criteria for assessing whether a headline indicates an {} {} towards quantum science & technology. Focus on understanding the criteria and applying them carefully to each headline independently.""".format(annot_feat, "/".join(annot_feat_classes) , annot_feat) for annot_feat, annot_feat_classes in annotation_classes.items()}
                context_prompt_2 = """Throughout the instructions, "quantum science & technology" encompasses not only the factual content of quantum theory but also the context, presentation, discussion, and interpretation of research practice on the topic. It also includes topic-related concepts or findings. """
                instruct_prompt_1 = {annot_feat : """Now, using the provided criteria, classify each headline independently as {} towards quantum science & technology. Only respond in the format "<#i#> {};". Never justify your responses.""".format(" or ".join(annotation_classes[annot_feat]), annot_feat) for annot_feat in annotation_classes.keys()}
                

                prompt_messages = [{"role": "user", "content": context_prompt_1[annot_feat]}, 
                                   {"role": "user", "content": context_prompt_2}]

                
                prompt_messages.append({"role": "user", "content": annotat_feature_intro_prompts[annot_feat] + annotation_criteria[annot_feat]})
                
                prompt_messages.extend([{"role": "user", "content": samples_intro_prompt + sample_separator.join(batch_art_inputs)},
                                        {"role": "user", "content": instruct_prompt_1[annot_feat]},
                                        ])
            else:
                context_prompt_1 = {annot_feat : """You are an annotator. Your task is to annotate a given set of article headlines on their {} towards quantum science & technology. The headlines correspond to news articles or press releases, which were referenced in science or technology related subreddits on Reddit. Your goal is to strictly adhere to the concept of sentiment for assessing whether a headline indicates an {} attitude towards quantum science & technology. Make sure to consider only the attitude towards the topic of quantum science & technology, not the overall {}. Focus on understanding what each headline expresses and classify each headline independently.""".format(annot_feat, "/".join(annot_feat_classes) , annot_feat) for annot_feat, annot_feat_classes in annotation_classes.items()}
                context_prompt_2 = """Throughout the instructions, "quantum science & technology" encompasses not only the factual content of quantum theory but also the context, presentation, discussion, and interpretation of research practice on the topic. It also includes topic-related concepts or findings. """
                instruct_prompt_1 = {annot_feat : """Now label each headline independently as {} towards quantum science & technology. Only respond in the format "<#i#> {};". Never justify your responses.""".format(" or ".join(annotation_classes[annot_feat]), annot_feat) for annot_feat in annotation_classes.keys()}
                

                prompt_messages = [{"role": "user", "content": context_prompt_1[annot_feat]}, 
                                   {"role": "user", "content": context_prompt_2}]


                prompt_messages.extend([{"role": "user", "content": samples_intro_prompt + sample_separator.join(batch_art_inputs)},
                                        {"role": "user", "content": instruct_prompt_1[annot_feat]},
                                        ])

            if verbose == -1:
                for message in prompt_messages:
                    print(message)
            chat_prompts[annot_feat].append({ "article_ids" : batch, "messages": prompt_messages})    

    
    return art_info_batched_collection, chat_prompts

# %%
annotation_classes = {"sentiment": ["positive", "negative", "neutral"],}


cmt_info_batched_collection, chat_prompts = gpt_prepare_batched_prompt(articles_df=stratified_art_df,
                                                                        annotation_classes=annotation_classes,
                                                                        include_annot_criteria=False,
                                                                        annotation_batch_size=25,
                                                                        verbose=0,
                                                                        )

print(cmt_info_batched_collection)
print(len(cmt_info_batched_collection))
complete_prompt_str = " "

for annot_feat in annotation_classes.keys():
    #print(chat_prompts[annot_feat][0]["messages"][])
    print("\n########\n".join([chat_prompts[annot_feat][0]["messages"][i]["content"] for i in range(len(chat_prompts[annot_feat][0]["messages"]))]))
    complete_prompt_str += "\n\n".join([chat_prompts[annot_feat][0]["messages"][i]["content"] for i in range(len(chat_prompts[annot_feat][0]["messages"]))])
    print("########")
    print("########")
    print("########")
    print("########")

encoding = encoding_for_model("gpt-3.5-turbo")

print(len(encoding.encode(complete_prompt_str)))
# Out:
# Prepared  5  batches of size  [25, 25, 25, 25, 23]  each
# Preparing batch  1  of  5  for annotation feature  sentiment
# Preparing batch  2  of  5  for annotation feature  sentiment
# Preparing batch  3  of  5  for annotation feature  sentiment
# Preparing batch  4  of  5  for annotation feature  sentiment
# Preparing batch  5  of  5  for annotation feature  sentiment
# [[{'article_id': '35d0f68bb7be2fee0fd0990932773e3ff794d66777632e9e5c5c104f78d9b534', 'batch_#': 1, 'article_#_in_batch': 1, 'headline': 'Google officially lays claim to quantum supremacy'}, {'article_id': 'd7fabb35ee22a2ac2b64906a450f26bb9197507a952d230da19bf4a195dbe1cf', 'batch_#': 1, 'article_#_in_batch': 2, 'headline': 'Could quantum mechanics explain the existence of space-time?'}, {'article_id': 'd508b4daa15ec8fd62acb2a37ae1c70b15013bfe81786fe408b1f984f1a7850a', 'batch_#': 1, 'article_#_in_batch': 3, 'headline': 'A weird physics theory is gaining traction. Another version of you might already know it.'}, {'article_id': 'cea1ee857ff66bf052c61dd4c10226bfd9bc3128c574b5033bd4d9aba32f1d72', 'batch_#': 1, 'article_#_in_batch': 4, 'headline': 'Minuscule drums push the limits of quantum weirdness'}, {'article_id': 'c297f9dd1ad34c426d0ba64b0b62f5a3e8d08985bc429f4d15b1fb6807ec6c75', 'batch_#': 1, 'article_#_in_batch': 5, 'headline': 'IBM is going to sell computers millions of times faster than any ever made'}, {'article_id': '3fb49c5829f403ce8579165971a9e274dd276ae1188eb0486ab1a9bfced37b6e', 'batch_#': 1, 'article_#_in_batch': 6, 'headline': 'Chinese photonic quantum computer demonstrates quantum supremacy'}, {'article_id': '567f9172509ac9c0cc5d143a4d822932d2ed7c2579a60e7df66d69a346581400', 'batch_#': 1, 'article_#_in_batch': 7, 'headline': 'IBM Reveals Quantum Computing Leap With 127-Qubit Processor | Digital Trends'}, {'article_id': '0c460d4fe2ccaf02a8ebb7f2781068508d6a1464195113843415b9e7e95b83d7', 'batch_#': 1, 'article_#_in_batch': 8, 'headline': 'Physicists Got a Quantum Computer to Work by Blasting It With the Fibonacci Sequence'}, {'article_id': '7fb30b8281af8185d53cf4a066048a05413ee901ad5e61b1b5c98baa3ea4808f', 'batch_#': 1, 'article_#_in_batch': 9, 'headline': "Google's Quantum Computer Just Accurately Simulated a Molecule For The First Time"}, {'article_id': 'fc4a2f9e9a2de71d422ab19b466c6f24cfa418709ff3f4b6f79999130679194d', 'batch_#': 1, 'article_#_in_batch': 10, 'headline': 'Physicists reverse time using quantum computer'}, {'article_id': 'e987fc7a843587719db03c4f014d84236021df215151b58332e9d60321fc8374', 'batch_#': 1, 'article_#_in_batch': 11, 'headline': 'Quantum Chip Brings 9,000 Years of Compute Down to Microseconds'}, {'article_id': '97d180af0aa24682c633ce8bde6accef045f396e665634307fc22afccb93c7ee', 'batch_#': 1, 'article_#_in_batch': 12, 'headline': 'Quantum Processor Completes 9,000 Years of Work in 36 Microseconds'}, {'article_id': '46e37ce201a00badaf602f026f9e6e256516a1bbec0d20f4021b8319fa9453cd', 'batch_#': 1, 'article_#_in_batch': 13, 'headline': 'Quantum physics requires imaginary numbers to explain reality'}, {'article_id': 'bcaed93f93cf90c4d24aaad5664fafef4c94faee13c785ea72976103738cc5b0', 'batch_#': 1, 'article_#_in_batch': 14, 'headline': 'U.S. hatches plan to build a quantum Internet that might be unhackable'}, {'article_id': 'e7c9f16fa12e6ba02c25f4f881791448d3e6ae860f982c12c8f9a95ac20a0bf5', 'batch_#': 1, 'article_#_in_batch': 15, 'headline': 'Press release: Breaking the warp barrier for faster-than-light travel'}, {'article_id': '02dcb8cb079fe6bf93b3855762205be5be8f5b48d9f3cd25ad5c30a4c369799b', 'batch_#': 1, 'article_#_in_batch': 16, 'headline': 'Google says its quantum computer is more than 100 million times faster than a regular computer chip'}, {'article_id': 'fe1b04f530fe136dcd9b1eeae8d90729f270660a59b448eccdf22fb650efdd2e', 'batch_#': 1, 'article_#_in_batch': 17, 'headline': "'Zeno effect' verified—atoms won't move while you watch"}, {'article_id': '95e8e700a8fe4128692b8d92ecacd583e7007015a7fd566c309b847098d652ca', 'batch_#': 1, 'article_#_in_batch': 18, 'headline': 'IBM makes significant breakthrough towards scalable quantum computers'}, {'article_id': 'aecbf075ee140d43c79ae518e6688437bc0d6a77943694db030c2c59de817ad7', 'batch_#': 1, 'article_#_in_batch': 19, 'headline': 'Record-setting quantum entanglement connects two atoms across 20 miles'}, {'article_id': 'fe3a81093124b4ef278b549b73c19c1445 ...
# 5
# You are an annotator. Your task is to annotate a given set of article headlines on their sentiment towards quantum science & technology. The headlines correspond to news articles or press releases, which were referenced in science or technology related subreddits on Reddit. Your goal is to strictly adhere to the concept of sentiment for assessing whether a headline indicates an positive/negative/neutral attitude towards quantum science & technology. Make sure to consider only the attitude towards the topic of quantum science & technology, not the overall sentiment. Focus on understanding what each headline expresses and classify each headline independently.
# ########
# Throughout the instructions, "quantum science & technology" encompasses not only the factual content of quantum theory but also the context, presentation, discussion, and interpretation of research practice on the topic. It also includes topic-related concepts or findings.
# ########
# Here are the article headlines for annotation:
#  <#1#> Google officially lays claim to quantum supremacy
#
#   <#2#> Could quantum mechanics explain the existence of space-time?
#
#   <#3#> A weird physics theory is gaining traction. Another version of you might already know it.
#
#   <#4#> Minuscule drums push the limits of quantum weirdness
#
#   <#5#> IBM is going to sell computers millions of times faster than any ever made
#
#   <#6#> Chinese photonic quantum computer demonstrates quantum supremacy
#
#   <#7#> IBM Reveals Quantum Computing Leap With 127-Qubit Processor | Digital Trends
#
#   <#8#> Physicists Got a Quantum Computer to Work by Blasting It With the Fibonacci Sequence
#
#   <#9#> Google's Quantum Computer Just Accurately Simulated a Molecule For The First Time
#
#   <#10#> Physicists reverse time using quantum computer
#
#   <#11#> Quantum Chip Brings 9,000 Years of Compute Down to Microseconds
#
#   <#12#> Quantum Processor Completes 9,000 Years of Work in 36 Microseconds
#
#   <#13#> Quantum physics requires imaginary numbers to explain reality
#
#   <#14#> U.S. hatches plan to build a quantum Internet that might be unhackable
#
#   <#15#> Press release: Breaking the warp barrier for faster-than-light travel
#
#   <#16#> Google says its quantum computer is more than 100 million times faster than a regular computer chip
#
#   <#17#> 'Zeno effect' verified—atoms won't move while you watch
#
#   <#18#> IBM makes significant breakthrough towards scalable quantum computers
#
#   <#19#> Record-setting quantum entanglement connects two atoms across 20 miles
#
#   <#20#> IBM says it will have thousands of quantum computers for sale by 2025
#
#   <#21#> Aliens Could Be Using Quantum Communications to Talk Across Interstellar Space
#
#   <#22#> Quantum interaction: 10,000 times faster than light
#
#   <#23#> Google’s New Chip Is a Stepping Stone to Quantum Computing Supremacy
#
#   <#24#> Researchers claim quantum breakthrough
#
#   <#25#> Quantum device performs 2.6 billion years of computation in 4 minutes
# ########
# Now label each headline independently as positive or negative or neutral towards quantum science & technology. Only respond in the format "<#i#> sentiment;". Never justify your responses.
# ########
# ########
# ########
# ########
# 698

# %%
results_backup_catcher = None

def generate_annotations(model_id, model_kwargs,articles_df, annotation_classes, include_annot_criteria, annotation_batch_size = 4, num_repetitions=1):
    
    responses = []
    consumed_tokens = 0


    art_info_batched_collection, chat_prompts = gpt_prepare_batched_prompt(articles_df=articles_df,
                                                                        annotation_classes=annotation_classes,
                                                                        include_annot_criteria=include_annot_criteria,
                                                                        annotation_batch_size=annotation_batch_size,
                                                                        verbose=0,
                                                                        )


    '''To prepare our output batch-wise, we need to prepare the output storage for each batch
    Since the batch size and the article ids should be same among different features, we can use any of the annotation features 
    to get the info before iterating over the annotation features. '''
    
    for b_i, _ in enumerate(chat_prompts[list(annotation_classes.keys())[0]]): #Iterate batches
        
        #The following is for the case we want to continue from a certain batch (e.g. when the API connection was lost)
        #if b_i < 202:
        #     continue
        
        print("Processing batch {} of {}".format(b_i+1, len(chat_prompts[list(annotation_classes.keys())[0]])))
        batch_annotations = []
        
        #Recall that chat_prompts contains two items: "article_ids" and "messages" of a single batch
        num_articles_in_batch = len(chat_prompts[list(annotation_classes.keys())[0]][b_i]["article_ids"])
        batch_article_indices = list(range(num_articles_in_batch))
        
        for art_i in batch_article_indices: #Prepare a storage for the annotations of each headline in the batch
            print("Article {} of batch {}".format(art_i+1, b_i+1))
            art_annotations = {}
            art_annotations["article_idx_in_batch"] = art_i+1
            art_annotations["article_id"] = chat_prompts[list(annotation_classes.keys())[0]][b_i]["article_ids"][art_i]
            batch_annotations.append(art_annotations)
        
        for annot_feat in annotation_classes.keys(): #Request annotationsm, parse them and save them in the batch_annotations
            feat_batch_prompt = chat_prompts[annot_feat][b_i]
            
            prompt_messages = feat_batch_prompt["messages"]
            
            print("Retrieving annotations for feature {} and batch {}".format(annot_feat, b_i+1))
            
            for retrieval_attempt in range(1000000):
                try:
                    response = openai.ChatCompletion.create(model=model_id,
                                                            messages=prompt_messages,
                                                            n=num_repetitions,
                                                            **model_kwargs
                                                            )
                except openai.error.APIError as e:
                    #Handle API error here, e.g. retry or log
                    print(f"OpenAI API returned an API Error: {e} for the {retrieval_attempt}th time")
                    print("Backing up results...")
                    results_backup_catcher = {"responses": responses, "cmt_info_batched_collection": cmt_info_batched_collection}
                    print("Waiting before retrying...")
                    time.sleep(60)
                    continue #Retry the request if an error occured
                    
                except openai.error.APIConnectionError as e:
                    #Handle connection error here
                    print(f"Failed to connect to OpenAI API: {e} for the {retrieval_attempt}th time")
                    print("Backing up results...")
                    results_backup_catcher = {"responses": responses, "cmt_info_batched_collection": cmt_info_batched_collection}
                    print("Waiting before retrying...")
                    time.sleep(60)
                    continue
                    
                except openai.error.RateLimitError as e:
                    #Handle rate limit error (we recommend using exponential backoff)
                    print(f"OpenAI API request exceeded rate limit: {e}")
                    print("Backing up results...")
                    results_backup_catcher = {"responses": responses, "cmt_info_batched_collection": cmt_info_batched_collection}
                    print("Waiting 60 seconds before retrying...")
                    time.sleep(300)
                    continue
                except openai.error.InvalidRequestError as e:    
                    print(f"OpenAI API returned an API Error: {e} for the {retrieval_attempt}th time")
                    print("Backing up results...")
                    results_backup_catcher = {"responses": responses, "cmt_info_batched_collection": cmt_info_batched_collection}
                    print("We just continue with the next batch, but please see the log to catch up on the lost samples...")
                    break
                else:
                    break #Break out of the retry loop if no error occured
                    
            
            print("Received response! Starting to parse annotations...")
            
            print("=================================")
            response_contents =  [ choice["message"]["content"] for choice in response["choices"]]
            print(response_contents)
            consumed_tokens += response["usage"]["total_tokens"]
            print("=================================")

            # Convert response to raw annotations:
            try: #Catch when the response strings can't properly be parsed into annotations
                for art_i in batch_article_indices:
                    #print(cmt_i)
                    batch_annotations[art_i][annot_feat] = [ ]
                    for rc in response_contents:
                        #print(rc)
                        rc = rc.strip()
                        temp_annot_str = rc.split("<#{}#>".format(art_i+1))[1]
                        art_annotation_str = temp_annot_str.split(";")[0]
                        #batch_annotations[cmt_i][annot_feat].append(cmt_annotation_str.lower())
                        for annot_class in annotation_classes[annot_feat]:
                            if annot_class in art_annotation_str.lower():
                                batch_annotations[art_i][annot_feat].append(annot_class)
                                break #Only one annotation per class is allowed
            except: 
                print("Response couldn't be parsed! Skipping batch {}...".format( b_i+1))
                print("We will print the response contents for reference and append the raw response to the output")
                print(response_contents)
                batch_annotations.append(response_contents)
                continue
        
        responses.extend([{"batch_id": b_i, "annotated_by": model_id, "labels": batch_annotations}])
        print("Batch {} completed!".format(b_i+1), "Sleeping to avoid exceeding the rate limit...")
        time.sleep(45)
 
    print("Warning: Used ", consumed_tokens, " tokens over all batches.")

    return art_info_batched_collection, responses

# %%
annotation_classes = {"sentiment": ["positive", "negative", "neutral"],}

art_info_batched_collection, chat_prompts = gpt_prepare_batched_prompt(articles_df=stratified_art_df,
                                                                        annotation_batch_size=20,
                                                                        annotation_classes=annotation_classes,
                                                                        include_annot_criteria=True,#True,
                                                                        verbose=0,
                                                                        )

print(art_info_batched_collection)
print(len(art_info_batched_collection))
complete_prompt_str = " "

for annot_feat in annotation_classes.keys():
    #print(chat_prompts[annot_feat][0]["messages"][])
    print("\n########\n".join([chat_prompts[annot_feat][0]["messages"][i]["content"] for i in range(len(chat_prompts[annot_feat][0]["messages"]))]))
    complete_prompt_str += "\n\n".join([chat_prompts[annot_feat][0]["messages"][i]["content"] for i in range(len(chat_prompts[annot_feat][0]["messages"]))])
    print("########")
    print("########")
    print("########")
    print("########")


encoding = encoding_for_model("gpt-3.5-turbo")

print(len(encoding.encode(complete_prompt_str)))
# Out:
# Prepared  7  batches of size  [20, 20, 20, 20, 20, 20, 3]  each
# Preparing batch  1  of  7  for annotation feature  sentiment
# Preparing batch  2  of  7  for annotation feature  sentiment
# Preparing batch  3  of  7  for annotation feature  sentiment
# Preparing batch  4  of  7  for annotation feature  sentiment
# Preparing batch  5  of  7  for annotation feature  sentiment
# Preparing batch  6  of  7  for annotation feature  sentiment
# Preparing batch  7  of  7  for annotation feature  sentiment
# [[{'article_id': '35d0f68bb7be2fee0fd0990932773e3ff794d66777632e9e5c5c104f78d9b534', 'batch_#': 1, 'article_#_in_batch': 1, 'headline': 'Google officially lays claim to quantum supremacy'}, {'article_id': 'd7fabb35ee22a2ac2b64906a450f26bb9197507a952d230da19bf4a195dbe1cf', 'batch_#': 1, 'article_#_in_batch': 2, 'headline': 'Could quantum mechanics explain the existence of space-time?'}, {'article_id': 'd508b4daa15ec8fd62acb2a37ae1c70b15013bfe81786fe408b1f984f1a7850a', 'batch_#': 1, 'article_#_in_batch': 3, 'headline': 'A weird physics theory is gaining traction. Another version of you might already know it.'}, {'article_id': 'cea1ee857ff66bf052c61dd4c10226bfd9bc3128c574b5033bd4d9aba32f1d72', 'batch_#': 1, 'article_#_in_batch': 4, 'headline': 'Minuscule drums push the limits of quantum weirdness'}, {'article_id': 'c297f9dd1ad34c426d0ba64b0b62f5a3e8d08985bc429f4d15b1fb6807ec6c75', 'batch_#': 1, 'article_#_in_batch': 5, 'headline': 'IBM is going to sell computers millions of times faster than any ever made'}, {'article_id': '3fb49c5829f403ce8579165971a9e274dd276ae1188eb0486ab1a9bfced37b6e', 'batch_#': 1, 'article_#_in_batch': 6, 'headline': 'Chinese photonic quantum computer demonstrates quantum supremacy'}, {'article_id': '567f9172509ac9c0cc5d143a4d822932d2ed7c2579a60e7df66d69a346581400', 'batch_#': 1, 'article_#_in_batch': 7, 'headline': 'IBM Reveals Quantum Computing Leap With 127-Qubit Processor | Digital Trends'}, {'article_id': '0c460d4fe2ccaf02a8ebb7f2781068508d6a1464195113843415b9e7e95b83d7', 'batch_#': 1, 'article_#_in_batch': 8, 'headline': 'Physicists Got a Quantum Computer to Work by Blasting It With the Fibonacci Sequence'}, {'article_id': '7fb30b8281af8185d53cf4a066048a05413ee901ad5e61b1b5c98baa3ea4808f', 'batch_#': 1, 'article_#_in_batch': 9, 'headline': "Google's Quantum Computer Just Accurately Simulated a Molecule For The First Time"}, {'article_id': 'fc4a2f9e9a2de71d422ab19b466c6f24cfa418709ff3f4b6f79999130679194d', 'batch_#': 1, 'article_#_in_batch': 10, 'headline': 'Physicists reverse time using quantum computer'}, {'article_id': 'e987fc7a843587719db03c4f014d84236021df215151b58332e9d60321fc8374', 'batch_#': 1, 'article_#_in_batch': 11, 'headline': 'Quantum Chip Brings 9,000 Years of Compute Down to Microseconds'}, {'article_id': '97d180af0aa24682c633ce8bde6accef045f396e665634307fc22afccb93c7ee', 'batch_#': 1, 'article_#_in_batch': 12, 'headline': 'Quantum Processor Completes 9,000 Years of Work in 36 Microseconds'}, {'article_id': '46e37ce201a00badaf602f026f9e6e256516a1bbec0d20f4021b8319fa9453cd', 'batch_#': 1, 'article_#_in_batch': 13, 'headline': 'Quantum physics requires imaginary numbers to explain reality'}, {'article_id': 'bcaed93f93cf90c4d24aaad5664fafef4c94faee13c785ea72976103738cc5b0', 'batch_#': 1, 'article_#_in_batch': 14, 'headline': 'U.S. hatches plan to build a quantum Internet that might be unhackable'}, {'article_id': 'e7c9f16fa12e6ba02c25f4f881791448d3e6ae860f982c12c8f9a95ac20a0bf5', 'batch_#': 1, 'article_#_in_batch': 15, 'headline': 'Press release: Breaking the warp barrier for faster-than-light travel'}, {'article_id': '02dcb8cb079fe6bf93b3855762205be5be8f5b48d9f3cd25ad5c30a4c369799b', 'batch_#': 1, 'article_#_in_batch': 16, 'headline': 'Google says its quantum computer is more than 100 million times faster than a regular computer chip'}, {'article_id': 'fe1b04f530fe136dcd9b1eeae8d90729f270660a59b448eccdf22fb650efdd2e', 'batch_#': 1, 'article_#_in_batch': 17, 'headline': "'Zeno effect' verified—atoms won't move while you watch"}, {'article_id': '95e8e700a8fe4128692b8d92ecacd583e7007015a7fd566c309b847098d652ca', 'batch_#': 1, 'article_#_in_batch': 18, 'headline': 'IBM makes significant breakthrough towards scalable quantum computers'}, {'article_id': 'aecbf075ee140d43c79ae518e6688437bc0d6a77943694db030c2c59de817ad7', 'batch_#': 1, 'article_#_in_batch': 19, 'headline': 'Record-setting quantum entanglement connects two atoms across 20 miles'}, {'article_id': 'fe3a81093124b4ef278b549b73c19c1445 ...
# 7
# You are an annotator. Your task is to annotate a given set of article headlines on their sentiment towards quantum science & technology. The headlines correspond to news articles or press releases, which were referenced in science or technology related subreddits on Reddit. Your goal is to strictly follow the given set of annotation criteria for assessing whether a headline indicates an positive/negative/neutral sentiment towards quantum science & technology. Focus on understanding the criteria and applying them carefully to each headline independently.
# ########
# Throughout the instructions, "quantum science & technology" encompasses not only the factual content of quantum theory but also the context, presentation, discussion, and interpretation of research practice on the topic. It also includes topic-related concepts or findings.
# ########
# Label sentiment towards quantum science & technology strictly only with positive, negative or neutral. The annotation criteria for each sentiment class are as follows:
# Positive attitude criteria:
# 	- The headline expresses enthusiasm, optimism, or excitement about quantum science & technology
# 	- The headline emphasizes or praises the benefits of quantum science & technology.
# 	- The headline suggests that quantum science & technology has a value or is an improvement for a specific field/sector.
# 	- The headline states that quantum science & technology has an advantage compared to something else (e.g. faster, safer, ...)
# Negative attitude criteria:
# 	- The headline expresses concern, worry, or skepticism about quantum science & technology.
# 	- The headline expresses frustration or disappointment with the current state of quantum science & technology.
# 	- The headline mentions potential negative consequences or risks associated with the use of quantum science & technology.
# 	- The headline suggests that quantum science & technology is a step backwards or a problem for a specific field/sector.
# 	- The headline states that quantum science & technology has a disadvantage compared to something else (e.g. slower, less secure, ...)
# Neutral attitude criteria:
# 	- The headline presents information or facts without expressing any clear positive or negative sentiment towards quantum science & technology.
# 	- The headline poses questions related to quantum science & technology without expressing any clear positive or negative sentiment towards the topic.
# 	- The headline acknowledges quantum science & technology without expressing any clear positive or negative sentiment towards the topic.
# ########
# Here are the article headlines for annotation:
#  <#1#> Google officially lays claim to quantum supremacy
#
#   <#2#> Could quantum mechanics explain the existence of space-time?
#
#   <#3#> A weird physics theory is gaining traction. Another version of you might already know it.
#
#   <#4#> Minuscule drums push the limits of quantum weirdness
#
#   <#5#> IBM is going to sell computers millions of times faster than any ever made
#
#   <#6#> Chinese photonic quantum computer demonstrates quantum supremacy
#
#   <#7#> IBM Reveals Quantum Computing Leap With 127-Qubit Processor | Digital Trends
#
#   <#8#> Physicists Got a Quantum Computer to Work by Blasting It With the Fibonacci Sequence
#
#   <#9#> Google's Quantum Computer Just Accurately Simulated a Molecule For The First Time
#
#   <#10#> Physicists reverse time using quantum computer
#
#   <#11#> Quantum Chip Brings 9,000 Years of Compute Down to Microseconds
#
#   <#12#> Quantum Processor Completes 9,000 Years of Work in 36 Microseconds
#
#   <#13#> Quantum physics requires imaginary numbers to explain reality
#
#   <#14#> U.S. hatches plan to build a quantum Internet that might be unhackable
#
#   <#15#> Press release: Breaking the warp barrier for faster-than-light travel
#
#   <#16#> Google says its quantum computer is more than 100 million times faster than a regular computer chip
#
#   <#17#> 'Zeno effect' verified—atoms won't move while you watch
#
#   <#18#> IBM makes significant breakthrough towards scalable quantum computers
#
#   <#19#> Record-setting quantum entanglement connects two atoms across 20 miles
#
#   <#20#> IBM says it will have thousands of quantum computers for sale by 2025
# ########
# Now, using the provided criteria, classify each headline independently as positive or negative or neutral towards quantum science & technology. Only respond in the format "<#i#> sentiment;". Never justify your responses.
# ########
# ########
# ########
# ########
# 901

# %%
cmt_info_batched_collection, responses = generate_annotations(model_id="gpt-4",#"gpt-4",
                                                            model_kwargs={"max_tokens": 800, "temperature": 1.2},
                                                            articles_df=stratified_art_df,
                                                            annotation_classes=annotation_classes,
                                                            include_annot_criteria=True,
                                                            annotation_batch_size=20,
                                                            num_repetitions=8,
                                                            )
with open("headline_nocriteria_lowT_responses.pkl", "wb") as f:
    pkl.dump(responses, f)     
                     
with open("art_info_collection.pkl", "wb") as f:
    pkl.dump(art_info_batched_collection, f)
# Out:
# Prepared  7  batches of size  [20, 20, 20, 20, 20, 20, 3]  each
# Preparing batch  1  of  7  for annotation feature  sentiment
# Preparing batch  2  of  7  for annotation feature  sentiment
# Preparing batch  3  of  7  for annotation feature  sentiment
# Preparing batch  4  of  7  for annotation feature  sentiment
# Preparing batch  5  of  7  for annotation feature  sentiment
# Preparing batch  6  of  7  for annotation feature  sentiment
# Preparing batch  7  of  7  for annotation feature  sentiment
# Processing batch 1 of 7
# Article 1 of batch 1
# Article 2 of batch 1
# Article 3 of batch 1
# Article 4 of batch 1
# Article 5 of batch 1
# Article 6 of batch 1
# Article 7 of batch 1
# Article 8 of batch 1
# Article 9 of batch 1
# Article 10 of batch 1
# Article 11 of batch 1
# Article 12 of batch 1
# Article 13 of batch 1
# Article 14 of batch 1
# Article 15 of batch 1
# Article 16 of batch 1
# Article 17 of batch 1
# Article 18 of batch 1
# Article 19 of batch 1
# Article 20 of batch 1
# Retrieving annotations for feature sentiment and batch 1
# Received response! Starting to parse annotations...
# =================================
# ['<#1#> Neutral; \n<#2#> Neutral; \n<#3#> Negative; \n<#4#> Positive; \n<#5#> Positive; \n<#6#> Positive; \n<#7#> Positive; \n<#8#> Positive; \n<#9#> Positive; \n<#10#> Neutral; \n<#11#> Positive; \n<#12#> Positive; \n<#13#> Neutral; \n<#14#> Positive; \n<#15#> Neutral; \n<#16#> Positive; \n<#17#> Neutral; \n<#18#> Positive; \n<#19#> Positive; \n<#20#> Positive;', '<#1#> Positive; \n<#2#> Neutral; \n<#3#> Neutral; \n<#4#> Neutral; \n<#5#> Positive; \n<#6#> Positive; \n<#7#> Positive; \n<#8#> Neutral; \n<#9#> Positive; \n<#10#> Neutral; \n<#11#> Positive; \n<#12#> Positive; \n<#13#> Neutral;\n<#14#> Positive; \n<#15#> Neutral; \n<#16#> Positive; \n<#17#> Neutral; \n<#18#> Positive; \n<#19#> Positive; \n<#20#> Positive;', '<#1#> Positive;\n<#2#> Neutral;\n<#3#> Neutral;\n<#4#> Neutral;\n<#5#> Positive;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Positive;\n<#9#> Positive;\n<#10#> Positive;\n<#11#> Positive;\n<#12#> Positive;\n<#13#> Neutral;\n<#14#> Positive;\n<#15#> Neutral;\n<#16#> Positive;\n<#17#> Neutral;\n<#18#> Positive;\n<#19#> Positive;\n<#20#> Positive;', '<#1#> Positive;\n<#2#> Neutral;\n<#3#> Neutral;\n<#4#> Positive;\n<#5#> Positive;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Positive;\n<#9#> Positive;\n<#10#> Positive;\n<#11#> Positive;\n<#12#> Positive;\n<#13#> Neutral;\n<#14#> Positive;\n<#15#> Neutral;\n<#16#> Positive;\n<#17#> Neutral;\n<#18#> Positive;\n<#19#> Positive;\n<#20#> Positive;', '<#1#> Positive; \n<#2#> Neutral; \n<#3#> Neutral; \n<#4#> Neutral; \n<#5#> Positive; \n<#6#> Positive; \n<#7#> Positive; \n<#8#> Positive; \n<#9#> Positive; \n<#10#> Positive; \n<#11#> Positive; \n<#12#> Positive; \n<#13#> Neutral; \n<#14#> Positive; \n<#15#> Neutral; \n<#16#> Positive; \n<#17#> Neutral; \n<#18#> Positive; \n<#19#> Positive; \n<#20#> Positive;', '<#1#> positive;\n<#2#> neutral;\n<#3#> neutral;\n<#4#> neutral;\n<#5#> positive;\n<#6#> positive;\n<#7#> positive;\n<#8#> positive;\n<#9#> positive;\n<#10#> positive;\n<#11#> positive;\n<#12#> positive;\n<#13#> neutral;\n<#14#> positive;\n<#15#> neutral;\n<#16#> positive;\n<#17#> neutral;\n<#18#> positive;\n<#19#> positive;\n<#20#> positive;', '<#1#> Positive;\n<#2#> Neutral;\n<#3#> Neutral;\n<#4#> Neutral;\n<#5#> Positive;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Neutral;\n<#9#> Positive;\n<#10#> Neutral;\n<#11#> Positive;\n<#12#> Positive;\n<#13#> Neutral;\n<#14#> Positive;\n<#15#> Neutral;\n<#16#> Positive;\n<#17#> Neutral;\n<#18#> Positive;\n<#19#> Neutral;\n<#20#> Positive;', '<#1#> Positive; \n<#2#> Neutral;\n<#3#> Neutral;\n<#4#> Neutral;\n<#5#> Positive;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Positive;\n<#9#> Positive;\n<#10#> Positive; \n<#11#> Positive;\n<#12#> Positive;\n<#13#> Neutral;\n<#14#> Positive;\n<#15#> Neutral;\n<#16#> Positive;\n<#17#> Positive; \n<#18#> Positive; \n<#19#> Positive;\n<#20#> Positive;']
# =================================
# Batch 1 completed! Sleeping to avoid exceeding the rate limit...
# Processing batch 2 of 7
# Article 1 of batch 2
# Article 2 of batch 2
# Article 3 of batch 2
# Article 4 of batch 2
# Article 5 of batch 2
# Article 6 of batch 2
# Article 7 of batch 2
# Article 8 of batch 2
# Article 9 of batch 2
# Article 10 of batch 2
# Article 11 of batch 2
# Article 12 of batch 2
# Article 13 of batch 2
# Article 14 of batch 2
# Article 15 of batch 2
# Article 16 of batch 2
# Article 17 of batch 2
# Article 18 of batch 2
# Article 19 of batch 2
# Article 20 of batch 2
# Retrieving annotations for feature sentiment and batch 2
# Received response! Starting to parse annotations...
# =================================
# ['<#1#> Neutral;\n<#2#> Positive;\n<#3#> Positive;\n<#4#> Positive;\n<#5#> Positive;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Neutral;\n<#9#> Neutral;\n<#10#> Positive;\n<#11#> Neutral;\n<#12#> Neutral;\n<#13#> Neutral;\n<#14#> Positive;\n<#15#> Positive;\n<#16#> Positive;\n<#17#> Positive;\n<#18#> Neutral;\n<#19#> Neutral;\n<#20#> Positive;', '<#1#> Neutral; \n<#2#> Positive; \n<#3#> Positive; \n<#4#> Positive; \n<#5#> Positive; \n<#6#> Positive; \n<#7#> Positive; \n<#8#> Neutral; \n<#9#> Neutral;  \n<#10#> Positive; \n<#11#> Neutral; \n<#12#> Neutral; \n<#13#> Neutral;  \n<#14#> Positive; \n<#15#> Positive;  \n<#16#> Positive;\n<#17#> Positive; \n<#18#> Neutral; \n<#19#> Positive; \n<#20#> Positive;', '<#1#> Neutral;\n<#2#> Positive;\n<#3#> Positive;\n<#4#> Positive;\n<#5#> Positive;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Neutral;\n<#9#> Neutral;\n<#10#> Positive;\n<#11#> Positive;\n<#12#> Neutral;\n<#13#> Neutral;\n<#14#> Positive;\n<#15#> Positive;\n<#16#> Positive;\n<#17#> Positive;\n<#18#> Neutral;\n<#19#> Positive;\n<#20#> Positive;', '<#1#> Neutral;\n<#2#> Positive;\n<#3#> Positive;\n<#4#> Positive;\n<#5#> Positive;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Neutral;\n<#9#> Neutral;\n<#10#> Positive;\n<#11#> Neutral;\n<#12#> Neutral;\n<#13#> Neutral;\n<#14#> Positive;\n<#15#> Positive;\n<#16#> Positive;\n<#17#> Positive;\n<#18#> Neutral;\n<#19#> Neutral;\n<#20#> Positive;', '<#1#> Neutral;\n<#2#> Positive;\n<#3#> Positive;\n<#4#> Positive;\n<#5#> Positive;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Neutral;\n<#9#> Neutral;\n<#10#> Positive;\n<#11#> Neutral;\n<#12#> Neutral;\n<#13#> Neutral;\n<#14#> Positive;\n<#15#> Positive;\n<#16#> Positive;\n<#17#> Positive;\n<#18#> Neutral;\n<#19#> Neutral;\n<#20#> Positive;', '<#1#> Neutral;\n<#2#> Positive;\n<#3#> Positive;\n<#4#> Positive;\n<#5#> Positive;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Neutral;\n<#9#> Neutral;\n<#10#> Positive;\n<#11#> Neutral;\n<#12#> Neutral;\n<#13#> Neutral;\n<#14#> Positive;\n<#15#> Positive;\n<#16#> Positive;\n<#17#> Positive;\n<#18#> Neutral;\n<#19#> Neutral;\n<#20#> Positive;', '<#1#> Neutral;\n<#2#> Positive;\n<#3#> Positive;\n<#4#> Positive;\n<#5#> Positive;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Neutral;\n<#9#> Neutral;\n<#10#> Positive;\n<#11#> Neutral;\n<#12#> Neutral;\n<#13#> Neutral;\n<#14#> Positive;\n<#15#> Positive;\n<#16#> Positive;\n<#17#> Positive;\n<#18#> Neutral;\n<#19#> Neutral;\n<#20#> Neutral;', '<#1#> Neutral;\n<#2#> Positive;\n<#3#> Positive;\n<#4#> Positive;\n<#5#> Positive;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Neutral;\n<#9#> Neutral;\n<#10#> Positive;\n<#11#> Positive;\n<#12#> Neutral;\n<#13#> Neutral;\n<#14#> Positive;\n<#15#> Positive;\n<#16#> Positive;\n<#17#> Positive;\n<#18#> Neutral;\n<#19#> Positive;\n<#20#> Positive;']
# =================================
# Batch 2 completed! Sleeping to avoid exceeding the rate limit...
# Processing batch 3 of 7
# Article 1 of batch 3
# Article 2 of batch 3
# Article 3 of batch 3
# Article 4 of batch 3
# Article 5 of batch 3
# Article 6 of batch 3
# Article 7 of batch 3
# Article 8 of batch 3
# Article 9 of batch 3
# Article 10 of batch 3
# Article 11 of batch 3
# Article 12 of batch 3
# Article 13 of batch 3
# Article 14 of batch 3
# Article 15 of batch 3
# Article 16 of batch 3
# Article 17 of batch 3
# Article 18 of batch 3
# Article 19 of batch 3
# Article 20 of batch 3
# Retrieving annotations for feature sentiment and batch 3
# Received response! Starting to parse annotations...
# =================================
# ['<#1#> Positive;\n<#2#> Neutral;\n<#3#> Negative;\n<#4#> Neutral;\n<#5#> Neutral;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Neutral;\n<#9#> Neutral;\n<#10#> Positive;\n<#11#> Neutral;\n<#12#> Positive;\n<#13#> Positive;\n<#14#> Positive;\n<#15#> Negative;\n<#16#> Neutral;\n<#17#> Neutral;\n<#18#> Negative;\n<#19#> Positive;\n<#20#> Positive;', '<#1#> Positive; \n<#2#> Neutral; \n<#3#> Negative; \n<#4#> Neutral; \n<#5#> Neutral; \n<#6#> Positive; \n<#7#> Positive; \n<#8#> Neutral; \n<#9#> Neutral; \n<#10#> Positive; \n<#11#> Neutral; \n<#12#> Positive; \n<#13#> Positive; \n<#14#> Positive; \n<#15#> Negative; \n<#16#> Neutral; \n<#17#> Positive; \n<#18#> Neutral; \n<#19#> Positive; \n<#20#> Positive;', '<#1#> Positive;\n<#2#> Neutral;\n<#3#> Negative;\n<#4#> Neutral;\n<#5#> Neutral;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Neutral;\n<#9#> Positive;\n<#10#> Positive;\n<#11#> Positive;\n<#12#> Positive;\n<#13#> Positive;\n<#14#> Positive;\n<#15#> Negative;\n<#16#> Neutral;\n<#17#> Positive;\n<#18#> Negative;\n<#19#>Positive;\n<#20#> Positive;', '<#1#> positive;\n<#2#> neutral;\n<#3#> negative;\n<#4#> neutral;\n<#5#> neutral;\n<#6#> positive;\n<#7#> positive;\n<#8#> neutral;\n<#9#> neutral;\n<#10#> positive;\n<#11#> neutral;\n<#12#> positive;\n<#13#> positive;\n<#14#> positive;\n<#15#> negative;\n<#16#> neutral;\n<#17#> positive;\n<#18#> negative;\n<#19#> positive;\n<#20#> positive;', '<#1#> positive; \n<#2#> neutral; \n<#3#> negative; \n<#4#> neutral; \n<#5#> positive; \n<#6#> positive; \n<#7#> positive; \n<#8#> positive; \n<#9#> positive; \n<#10#> positive; \n<#11#> positive; \n<#12#> positive; \n<#13#> positive; \n<#14#> positive; \n<#15#> negative; \n<#16#> neutral; \n<#17#> positive; \n<#18#> neutral; \n<#19#> positive; \n<#20#> positive;', '<#1#> Positive;\n<#2#> Neutral; \n<#3#> Negative;\n<#4#> Neutral; \n<#5#> Positive; \n<#6#> Positive;\n<#7#> Positive; \n<#8#> Neutral; \n<#9#> Neutral;\n<#10#> Positive;\n<#11#> Positive;\n<#12#> Positive;  \n<#13#> Positive;\n<#14#> Positive; \n<#15#> Negative;\n<#16#> Neutral;\n<#17#> Positive; \n<#18#> Neutral;\n<#19#> Positive;\n<#20#> Positive;', '<#1#> Positive;\n<#2#> Neutral;\n<#3#> Negative;\n<#4#> Neutral;\n<#5#> Positive;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Positive;\n<#9#> Positive;\n<#10#> Positive;\n<#11#> Positive;\n<#12#> Positive;\n<#13#> Positive;\n<#14#> Positive;\n<#15#> Negative;\n<#16#> Neutral;\n<#17#> Positive;\n<#18#> Negative;\n<#19#> Positive;\n<#20#> Positive;', '<#1#> Positive;\n<#2#> Neutral;\n<#3#> Negative;\n<#4#> Neutral;\n<#5#> Positive;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Positive;\n<#9#> Neutral;\n<#10#> Positive;\n<#11#> Positive;\n<#12#> Positive;\n<#13#> Positive;\n<#14#> Positive;\n<#15#> Negative;\n<#16#> Neutral;\n<#17#> Positive;\n<#18#> Neutral;\n<#19#> Positive;\n<#20#> Positive;']
# =================================
# Batch 3 completed! Sleeping to avoid exceeding the rate limit...
# Processing batch 4 of 7
# Article 1 of batch 4
# Article 2 of batch 4
# Article 3 of batch 4
# Article 4 of batch 4
# Article 5 of batch 4
# Article 6 of batch 4
# Article 7 of batch 4
# Article 8 of batch 4
# Article 9 of batch 4
# Article 10 of batch 4
# Article 11 of batch 4
# Article 12 of batch 4
# Article 13 of batch 4
# Article 14 of batch 4
# Article 15 of batch 4
# Article 16 of batch 4
# Article 17 of batch 4
# Article 18 of batch 4
# Article 19 of batch 4
# Article 20 of batch 4
# Retrieving annotations for feature sentiment and batch 4
# Received response! Starting to parse annotations...
# =================================
# ['<#1#> Neutral;\n<#2#> Neutral;\n<#3#> Neutral;\n<#4#> Positive;\n<#5#> Negative;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Positive;\n<#9#> Positive;\n<#10#> Positive;\n<#11#> Positive;\n<#12#> Neutral;\n<#13#> Positive;\n<#14#> Positive;\n<#15#> Neutral; \n<#16#> Neutral; \n<#17#> Positive;\n<#18#> Positive;\n<#19#> Positive;\n<#20#> Neutral;', '<#1#> Neutral;\n<#2#> Neutral;\n<#3#> Neutral;\n<#4#> Positive;\n<#5#> Negative;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Positive;\n<#9#> Positive;\n<#10#> Positive;\n<#11#> Positive;\n<#12#> Neutral;\n<#13#> Positive;\n<#14#> Positive;\n<#15#> Negative;\n<#16#> Neutral;\n<#17#> Positive;\n<#18#> Positive;\n<#19#> Positive;\n<#20#> Neutral;', '<#1#> Neutral;\n<#2#> Neutral;\n<#3#> Neutral;\n<#4#> Positive;\n<#5#> Negative;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Positive;\n<#9#> Positive;\n<#10#> Positive;\n<#11#> Positive;\n<#12#> Neutral;\n<#13#> Positive;\n<#14#> Positive;\n<#15#> Neutral;\n<#16#> Neutral;\n<#17#> Positive;\n<#18#> Positive;\n<#19#> Positive;\n<#20#> Neutral;', '<#1#> Neutral;\n<#2#> Neutral;\n<#3#> Neutral;\n<#4#> Positive;\n<#5#> Negative;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Positive;\n<#9#> Positive;\n<#10#> Positive;\n<#11#> Positive;\n<#12#> Neutral;\n<#13#> Positive;\n<#14#> Positive;\n<#15#> Negative;\n<#16#> Neutral;\n<#17#> Positive;\n<#18#> Positive;\n<#19#> Positive;\n<#20#> Neutral;', '<#1#> Neutral;\n<#2#> Neutral;\n<#3#> Neutral;\n<#4#> Positive;\n<#5#> Negative;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Positive;\n<#9#> Positive;\n<#10#> Positive;\n<#11#> Positive;\n<#12#> Neutral;\n<#13#> Positive;\n<#14#> Positive;\n<#15#> Neutral;\n<#16#> Neutral;\n<#17#> Positive;\n<#18#> Positive;\n<#19#> Positive;\n<#20#> Positive;', '<#1#> Neutral;\n<#2#> Neutral;\n<#3#> Neutral;\n<#4#> Positive;\n<#5#> Negative;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Positive;\n<#9#> Positive;\n<#10#> Positive;\n<#11#> Positive;\n<#12#> Neutral;\n<#13#> Positive;\n<#14#> Positive;\n<#15#> Negative;\n<#16#> Positive;\n<#17#> Positive;\n<#18#> Positive;\n<#19#> Positive;\n<#20#> Neutral;', '<#1#> Neutral;\n<#2#> Neutral;\n<#3#> Neutral;\n<#4#> Positive;\n<#5#> Negative;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Positive;\n<#9#> Positive;\n<#10#> Positive;\n<#11#> Positive;\n<#12#> Neutral;\n<#13#> Positive;\n<#14#> Positive;\n<#15#> Neutral;\n<#16#> Neutral;\n<#17#> Positive;\n<#18#> Positive;\n<#19#> Positive;\n<#20#> Positive;', '<#1#> Neutral;\n<#2#> Neutral;\n<#3#> Neutral;\n<#4#> Positive;\n<#5#> Negative;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Positive;\n<#9#> Positive;\n<#10#> Positive;\n<#11#> Positive;\n<#12#> Neutral;\n<#13#> Positive;\n<#14#> Positive;\n<#15#> Neutral;\n<#16#> Neutral;\n<#17#> Positive;\n<#18#> Positive;\n<#19#> Positive;\n<#20#> Neutral;']
# =================================
# Batch 4 completed! Sleeping to avoid exceeding the rate limit...
# Processing batch 5 of 7
# Article 1 of batch 5
# Article 2 of batch 5
# Article 3 of batch 5
# Article 4 of batch 5
# Article 5 of batch 5
# Article 6 of batch 5
# Article 7 of batch 5
# Article 8 of batch 5
# Article 9 of batch 5
# Article 10 of batch 5
# Article 11 of batch 5
# Article 12 of batch 5
# Article 13 of batch 5
# Article 14 of batch 5
# Article 15 of batch 5
# Article 16 of batch 5
# Article 17 of batch 5
# Article 18 of batch 5
# Article 19 of batch 5
# Article 20 of batch 5
# Retrieving annotations for feature sentiment and batch 5
# Received response! Starting to parse annotations...
# =================================
# ['<#1#> Positive;\n<#2#> Positive;\n<#3#> Positive;\n<#4#> Positive;\n<#5#> Neutral;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Neutral;\n<#9#> Positive;\n<#10#> Neutral;\n<#11#> Positive;\n<#12#> Positive;\n<#13#> Neutral;\n<#14#> Positive;\n<#15#> Positive;\n<#16#> Neutral;\n<#17#> Positive;\n<#18#> Positive;\n<#19#> Neutral;\n<#20#> Positive;', '<#1#> Positive;\n<#2#> Positive;\n<#3#> Positive;\n<#4#> Positive;\n<#5#> Negative;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Neutral;\n<#9#> Neutral;\n<#10#> Neutral;\n<#11#> Positive;\n<#12#> Positive;\n<#13#> Neutral;\n<#14#> Positive;\n<#15#> Positive;\n<#16#> Neutral;\n<#17#> Positive;\n<#18#> Positive;\n<#19#> Neutral;\n<#20#> Positive;', '<#1#> Positive;\n<#2#> Positive;\n<#3#> Positive;\n<#4#> Positive;\n<#5#> Neutral;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Neutral;\n<#9#> Neutral;\n<#10#> Neutral;\n<#11#> Positive;\n<#12#> Positive;\n<#13#> Neutral;\n<#14#> Positive;\n<#15#> Positive;\n<#16#> Neutral;\n<#17#> Positive;\n<#18#> Positive;\n<#19#> Neutral;\n<#20#> Positive;', '<#1#> Positive;\n<#2#> Positive;\n<#3#> Positive;\n<#4#> Positive;\n<#5#> Neutral;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Neutral;\n<#9#> Neutral;\n<#10#> Neutral;\n<#11#> Positive;\n<#12#> Positive;\n<#13#> Neutral;\n<#14#> Positive;\n<#15#> Positive;\n<#16#> Neutral;\n<#17#> Positive;\n<#18#> Positive;\n<#19#> Neutral;\n<#20#> Positive;', '<#1#> Positive;\n<#2#> Positive;\n<#3#> Positive;\n<#4#> Positive;\n<#5#> Neutral;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Neutral;\n<#9#> Positive;\n<#10#> Neutral;\n<#11#> Positive;\n<#12#> Positive;\n<#13#> Neutral;\n<#14#> Positive;\n<#15#> Positive;\n<#16#> Neutral;\n<#17#> Positive;\n<#18#> Positive;\n<#19#> Neutral;\n<#20#> Positive;', '<#1#> Positive;\n<#2#> Positive;\n<#3#> Positive;\n<#4#> Positive;\n<#5#> Negative;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Neutral;\n<#9#> Neutral;\n<#10#> Neutral;\n<#11#> Positive;\n<#12#> Positive;\n<#13#> Neutral;\n<#14#> Positive;\n<#15#> Positive;\n<#16#> Neutral;\n<#17#> Positive;\n<#18#> Positive;\n<#19#> Neutral;\n<#20#> Positive;', '<#1#> Positive;\n<#2#> Positive;\n<#3#> Positive;\n<#4#> Positive;\n<#5#> Negative;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Neutral;\n<#9#> Neutral;\n<#10#> Neutral;\n<#11#> Positive;\n<#12#> Positive;\n<#13#> Neutral;\n<#14#> Positive;\n<#15#> Positive;\n<#16#> Neutral;\n<#17#> Positive;\n<#18#> Positive;\n<#19#> Neutral;\n<#20#> Positive;', '<#1#> Neutral;\n<#2#> Neutral;\n<#3#> Positive;\n<#4#> Neutral;\n<#5#> Negative;\n<#6#> Neutral;\n<#7#> Positive;\n<#8#> Neutral;\n<#9#> Neutral;\n<#10#> Neutral;\n<#11#> Positive;\n<#12#> Neutral;\n<#13#> Neutral;\n<#14#> Positive;\n<#15#>/ Positive;\n<#16#> Neutral;\n<#17#> Positive;\n<#18#> Positive;\n<#19#> Neutral;\n<#20#> Neutral;']
# =================================
# Batch 5 completed! Sleeping to avoid exceeding the rate limit...
# Processing batch 6 of 7
# Article 1 of batch 6
# Article 2 of batch 6
# Article 3 of batch 6
# Article 4 of batch 6
# Article 5 of batch 6
# Article 6 of batch 6
# Article 7 of batch 6
# Article 8 of batch 6
# Article 9 of batch 6
# Article 10 of batch 6
# Article 11 of batch 6
# Article 12 of batch 6
# Article 13 of batch 6
# Article 14 of batch 6
# Article 15 of batch 6
# Article 16 of batch 6
# Article 17 of batch 6
# Article 18 of batch 6
# Article 19 of batch 6
# Article 20 of batch 6
# Retrieving annotations for feature sentiment and batch 6
# Received response! Starting to parse annotations...
# =================================
# ['<#1#> Neutral;\n<#2#> Positive;\n<#3#> Neutral;\n<#4#> Neutral;\n<#5#> Positive;\n<#6#> Neutral;\n<#7#> Neutral;\n<#8#> Negative;\n<#9#> Positive;\n<#10#> Negative;\n<#11#> Positive;\n<#12#> Neutral;\n<#13#> Positive;\n<#14#> Positive;\n<#15#> Neutral;\n<#16#> Positive;\n<#17#> Neutral;\n<#18#> Positive;\n<#19#> Positive;\n<#20#> Positive;', '<#1#> neutral;\n<#2#> positive;\n<#3#> neutral;\n<#4#> neutral;\n<#5#> positive;\n<#6#> neutral;\n<#7#> neutral;\n<#8#> negative;\n<#9#> positive;\n<#10#> negative;\n<#11#> positive;\n<#12#> positive;\n<#13#> positive;\n<#14#> positive;\n<#15#> neutral;\n<#16#> positive;\n<#17#> positive;\n<#18#> neutral;\n<#19#> neutral;\n<#20#> positive;', '<#1#> Neutral;\n<#2#> Positive;\n<#3#> Neutral;\n<#4#> Neutral;\n<#5#> Positive;\n<#6#> Positive;\n<#7#> Neutral;\n<#8#> Negative;\n<#9#> Positive;\n<#10#> Negative;\n<#11#> Positive;\n<#12#> Positive;\n<#13#> Positive;\n<#14#> Positive;\n<#15#> Neutral;\n<#16#> Positive;\n<#17#> Neutral;\n<#18#> Positive;\n<#19#> Positive;\n<#20#> Positive;', '<#1#> Neutral;\n<#2#> Positive;\n<#3#> Negative;\n<#4#> Neutral;\n<#5#> Positive;\n<#6#> Positive;\n<#7#> Neutral;\n<#8#> Negative;\n<#9#> Neutral;\n<#10#> Negative;\n<#11#> Positive;\n<#12#> Neutral;\n<#13#> Positive;\n<#14#> Positive;\n<#15#> Neutral;\n<#16#> Positive;\n<#17#> Positive;\n<#18#> Positive;\n<#19#> Positive;\n<#20#> Positive;', '<#1#> Neutral; \n<#2#> Positive; \n<#3#> Neutral; \n<#4#> Neutral; \n<#5#> Positive; \n<#6#> Positive; \n<#7#> Neutral; \n<#8#> Negative; \n<#9#> Positive; \n<#10#> Negative; \n<#11#> Positive; \n<#12#> Positive; \n<#13#> Positive; \n<#14#> Positive; \n<#15#> Neutral; \n<#16#> Positive; \n<#17#> Positive; \n<#18#> Positive; \n<#19#> Positive; \n<#20#> Positive;', '<#1#> Neutral;\n<#2#> Positive;\n<#3#> Negative;\n<#4#> Neutral;\n<#5#> Positive;\n<#6#> Neutral;\n<#7#> Neutral;\n<#8#> Negative;\n<#9#> Positive;\n<#10#> Neutral;\n<#11#> Positive;\n<#12#> Positive;\n<#13#> Positive;\n<#14#> Positive;\n<#15#> Neutral;\n<#16#> Positive;\n<#17#> Positive;\n<#18#> Positive;\n<#19#> Positive;\n<#20#> Positive;', '<#1#> Neutral;\n<#2#> Positive;\n<#3#> Negative;\n<#4#> Neutral;\n<#5#> Positive;\n<#6#> Neutral;\n<#7#> Neutral;\n<#8#> Negative;\n<#9#> Positive;\n<#10#> Negative;\n<#11#> Positive;\n<#12#> Positive;\n<#13#> Positive;\n<#14#> Positive;\n<#15#> Neutral;\n<#16#> Positive;\n<#17#> Positive;\n<#18#> Positive;\n<#19#> Positive;\n<#20#> Positive;', '<#1#> Neutral;\n<#2#> Positive;\n<#3#> Neutral;\n<#4#> Neutral;\n<#5#> Positive;\n<#6#> Positive;\n<#7#> Positive;\n<#8#> Negative;\n<#9#> Positive; \n<#10#> Negative; \n<#11#> Positive; \n<#12#> Positive;\n<#13#> Positive;\n<#14#> Positive;\n<#15#> Neutral; \n<#16#> Positive; \n<#17#> Positive; \n<#18#> Neutral; \n<#19#> Positive; \n<#20#> Positive;']
# =================================
# Batch 6 completed! Sleeping to avoid exceeding the rate limit...
# Processing batch 7 of 7
# Article 1 of batch 7
# Article 2 of batch 7
# Article 3 of batch 7
# Retrieving annotations for feature sentiment and batch 7
# Received response! Starting to parse annotations...
# =================================
# ['<#1#> Positive;\n<#2#> Negative;\n<#3#> Neutral;', '<#1#> Positive; \n<#2#> Negative; \n<#3#> Neutral;', '<#1#> Positive;\n<#2#> Negative;\n<#3#> Neutral;', '<#1#> Positive;\n<#2#> Negative;\n<#3#> Neutral;', '<#1#> Positive; \n\n<#2#> Negative;\n\n<#3#> Neutral;', '<#1#> Positive; \n<#2#> Negative; \n<#3#> Neutral;', '<#1#> Positive; \n<#2#> Negative; \n<#3#> Neutral;', '<#1#> Positive;\n<#2#> Negative;\n<#3#> Neutral;']
# =================================
# Batch 7 completed! Sleeping to avoid exceeding the rate limit...
# Warning: Used  13114  tokens over all batches.

# %%
print(responses)
# Out:
# [{'batch_id': 0, 'annotated_by': 'gpt-4', 'labels': [{'article_idx_in_batch': 1, 'article_id': '35d0f68bb7be2fee0fd0990932773e3ff794d66777632e9e5c5c104f78d9b534', 'sentiment': ['neutral', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive']}, {'article_idx_in_batch': 2, 'article_id': 'd7fabb35ee22a2ac2b64906a450f26bb9197507a952d230da19bf4a195dbe1cf', 'sentiment': ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']}, {'article_idx_in_batch': 3, 'article_id': 'd508b4daa15ec8fd62acb2a37ae1c70b15013bfe81786fe408b1f984f1a7850a', 'sentiment': ['negative', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']}, {'article_idx_in_batch': 4, 'article_id': 'cea1ee857ff66bf052c61dd4c10226bfd9bc3128c574b5033bd4d9aba32f1d72', 'sentiment': ['positive', 'neutral', 'neutral', 'positive', 'neutral', 'neutral', 'neutral', 'neutral']}, {'article_idx_in_batch': 5, 'article_id': 'c297f9dd1ad34c426d0ba64b0b62f5a3e8d08985bc429f4d15b1fb6807ec6c75', 'sentiment': ['positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive']}, {'article_idx_in_batch': 6, 'article_id': '3fb49c5829f403ce8579165971a9e274dd276ae1188eb0486ab1a9bfced37b6e', 'sentiment': ['positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive']}, {'article_idx_in_batch': 7, 'article_id': '567f9172509ac9c0cc5d143a4d822932d2ed7c2579a60e7df66d69a346581400', 'sentiment': ['positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive']}, {'article_idx_in_batch': 8, 'article_id': '0c460d4fe2ccaf02a8ebb7f2781068508d6a1464195113843415b9e7e95b83d7', 'sentiment': ['positive', 'neutral', 'positive', 'positive', 'positive', 'positive', 'neutral', 'positive']}, {'article_idx_in_batch': 9, 'article_id': '7fb30b8281af8185d53cf4a066048a05413ee901ad5e61b1b5c98baa3ea4808f', 'sentiment': ['positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive']}, {'article_idx_in_batch': 10, 'article_id': 'fc4a2f9e9a2de71d422ab19b466c6f24cfa418709ff3f4b6f79999130679194d', 'sentiment': ['neutral', 'neutral', 'positive', 'positive', 'positive', 'positive', 'neutral', 'positive']}, {'article_idx_in_batch': 11, 'article_id': 'e987fc7a843587719db03c4f014d84236021df215151b58332e9d60321fc8374', 'sentiment': ['positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive']}, {'article_idx_in_batch': 12, 'article_id': '97d180af0aa24682c633ce8bde6accef045f396e665634307fc22afccb93c7ee', 'sentiment': ['positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive']}, {'article_idx_in_batch': 13, 'article_id': '46e37ce201a00badaf602f026f9e6e256516a1bbec0d20f4021b8319fa9453cd', 'sentiment': ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']}, {'article_idx_in_batch': 14, 'article_id': 'bcaed93f93cf90c4d24aaad5664fafef4c94faee13c785ea72976103738cc5b0', 'sentiment': ['positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive']}, {'article_idx_in_batch': 15, 'article_id': 'e7c9f16fa12e6ba02c25f4f881791448d3e6ae860f982c12c8f9a95ac20a0bf5', 'sentiment': ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']}, {'article_idx_in_batch': 16, 'article_id': '02dcb8cb079fe6bf93b3855762205be5be8f5b48d9f3cd25ad5c30a4c369799b', 'sentiment': ['positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive']}, {'article_idx_in_batch': 17, 'article_id': 'fe1b04f530fe136dcd9b1eeae8d90729f270660a59b448eccdf22fb650efdd2e', 'sentiment': ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'positive']}, {'article_idx_in_batch': 18, 'article_id': '95e8e700a8fe4128692b8d92ecacd583e7007015a7fd566c309b847098d652ca', 'sentiment': ['positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'posit ...

# %%
num_of_cmts = 0
for cmt_info_batch in cmt_info_batched_collection:
    num_of_cmts += len(cmt_info_batch)
    for cmt_info in cmt_info_batch:
        print(cmt_info)
        
print(num_of_cmts)
# Out:
# {'article_id': '35d0f68bb7be2fee0fd0990932773e3ff794d66777632e9e5c5c104f78d9b534', 'batch_#': 1, 'article_#_in_batch': 1, 'headline': 'Google officially lays claim to quantum supremacy'}
# {'article_id': 'd7fabb35ee22a2ac2b64906a450f26bb9197507a952d230da19bf4a195dbe1cf', 'batch_#': 1, 'article_#_in_batch': 2, 'headline': 'Could quantum mechanics explain the existence of space-time?'}
# {'article_id': 'd508b4daa15ec8fd62acb2a37ae1c70b15013bfe81786fe408b1f984f1a7850a', 'batch_#': 1, 'article_#_in_batch': 3, 'headline': 'A weird physics theory is gaining traction. Another version of you might already know it.'}
# {'article_id': 'cea1ee857ff66bf052c61dd4c10226bfd9bc3128c574b5033bd4d9aba32f1d72', 'batch_#': 1, 'article_#_in_batch': 4, 'headline': 'Minuscule drums push the limits of quantum weirdness'}
# {'article_id': 'c297f9dd1ad34c426d0ba64b0b62f5a3e8d08985bc429f4d15b1fb6807ec6c75', 'batch_#': 1, 'article_#_in_batch': 5, 'headline': 'IBM is going to sell computers millions of times faster than any ever made'}
# {'article_id': '3fb49c5829f403ce8579165971a9e274dd276ae1188eb0486ab1a9bfced37b6e', 'batch_#': 1, 'article_#_in_batch': 6, 'headline': 'Chinese photonic quantum computer demonstrates quantum supremacy'}
# {'article_id': '567f9172509ac9c0cc5d143a4d822932d2ed7c2579a60e7df66d69a346581400', 'batch_#': 1, 'article_#_in_batch': 7, 'headline': 'IBM Reveals Quantum Computing Leap With 127-Qubit Processor | Digital Trends'}
# {'article_id': '0c460d4fe2ccaf02a8ebb7f2781068508d6a1464195113843415b9e7e95b83d7', 'batch_#': 1, 'article_#_in_batch': 8, 'headline': 'Physicists Got a Quantum Computer to Work by Blasting It With the Fibonacci Sequence'}
# {'article_id': '7fb30b8281af8185d53cf4a066048a05413ee901ad5e61b1b5c98baa3ea4808f', 'batch_#': 1, 'article_#_in_batch': 9, 'headline': "Google's Quantum Computer Just Accurately Simulated a Molecule For The First Time"}
# {'article_id': 'fc4a2f9e9a2de71d422ab19b466c6f24cfa418709ff3f4b6f79999130679194d', 'batch_#': 1, 'article_#_in_batch': 10, 'headline': 'Physicists reverse time using quantum computer'}
# {'article_id': 'e987fc7a843587719db03c4f014d84236021df215151b58332e9d60321fc8374', 'batch_#': 1, 'article_#_in_batch': 11, 'headline': 'Quantum Chip Brings 9,000 Years of Compute Down to Microseconds'}
# {'article_id': '97d180af0aa24682c633ce8bde6accef045f396e665634307fc22afccb93c7ee', 'batch_#': 1, 'article_#_in_batch': 12, 'headline': 'Quantum Processor Completes 9,000 Years of Work in 36 Microseconds'}
# {'article_id': '46e37ce201a00badaf602f026f9e6e256516a1bbec0d20f4021b8319fa9453cd', 'batch_#': 1, 'article_#_in_batch': 13, 'headline': 'Quantum physics requires imaginary numbers to explain reality'}
# {'article_id': 'bcaed93f93cf90c4d24aaad5664fafef4c94faee13c785ea72976103738cc5b0', 'batch_#': 1, 'article_#_in_batch': 14, 'headline': 'U.S. hatches plan to build a quantum Internet that might be unhackable'}
# {'article_id': 'e7c9f16fa12e6ba02c25f4f881791448d3e6ae860f982c12c8f9a95ac20a0bf5', 'batch_#': 1, 'article_#_in_batch': 15, 'headline': 'Press release: Breaking the warp barrier for faster-than-light travel'}
# {'article_id': '02dcb8cb079fe6bf93b3855762205be5be8f5b48d9f3cd25ad5c30a4c369799b', 'batch_#': 1, 'article_#_in_batch': 16, 'headline': 'Google says its quantum computer is more than 100 million times faster than a regular computer chip'}
# {'article_id': 'fe1b04f530fe136dcd9b1eeae8d90729f270660a59b448eccdf22fb650efdd2e', 'batch_#': 1, 'article_#_in_batch': 17, 'headline': "'Zeno effect' verified—atoms won't move while you watch"}
# {'article_id': '95e8e700a8fe4128692b8d92ecacd583e7007015a7fd566c309b847098d652ca', 'batch_#': 1, 'article_#_in_batch': 18, 'headline': 'IBM makes significant breakthrough towards scalable quantum computers'}
# {'article_id': 'aecbf075ee140d43c79ae518e6688437bc0d6a77943694db030c2c59de817ad7', 'batch_#': 1, 'article_#_in_batch': 19, 'headline': 'Record-setting quantum entanglement connects two atoms across 20 miles'}
# {'article_id': 'fe3a81093124b4ef278b549b73c19c1445612870b1b41e85983cd8d9d6c4e6f1', 'batch_#': 1, 'article_#_in_batch': 20, 'headline': 'IBM says it will have thousands of quantum computers for sale by 2025'}
# {'article_id': '03757a5a3fa20fadf5a935d1415cf4f413258347a8d62d7fc3a9467ac48786a0', 'batch_#': 2, 'article_#_in_batch': 1, 'headline': 'Aliens Could Be Using Quantum Communications to Talk Across Interstellar Space'}
# {'article_id': '59b4ae6bcd3d51039b4433e1529d7028fbccf1e8b5521346127a7456b73d2709', 'batch_#': 2, 'article_#_in_batch': 2, 'headline': 'Quantum interaction: 10,000 times faster than light'}
# {'article_id': '91fedf335be37f1bacc5d0e395f1169bb3d3180d61748375aae332bada4960ec', 'batch_#': 2, 'article_#_in_batch': 3, 'headline': 'Google’s New Chip Is a Stepping Stone to Quantum Computing Supremacy'}
# {'article_id': '901967680a3b4787b39a6beb15dea997d6f637d168f631e60f680399085b267b', 'batch_#': 2, 'article_#_in_batch': 4, 'headline': 'Researchers claim quantum breakthrough'}
# {'article_id': '195b83a2f954744904be0f5234ab1e311c8a9d35b057e0a2a744f04904702e6f', 'batch_#': 2, 'article_#_in_batch': 5, 'headline': 'Quantum device performs 2.6 billion years of computation in 4 minutes'}
# {'article_id': '6e8abe0d7c2dd8a173f20417dd695b202df68e1164f4519c6ee8a343485dc82a', 'batch_#': 2, 'article_#_in_batch': 6, 'headline': 'Quantum Teleportation Was Just Achieved With 90% Accuracy Over a 44km Distance'}
# {'article_id': 'aa06fc7c6e7cf20045c33d58c4806fa3fa37ded6cd7661c5b1ddc0e37edd108c', 'batch_#': 2, 'article_#_in_batch': 7, 'headline': "Google: We've made 'quantum supremacy' breakthrough with 54-qubit Sycamore chip"}
# {'article_id': '9aa9b7b6262e5b005032ded6f66456e7f78cc7d76edda40114d37ef27bc1cb12', 'batch_#': 2, 'article_#_in_batch': 8, 'headline': "Quantum 'spookiness' passes toughest test yet"}
# {'article_id': '29297764d823210c31d28168deeb30a91e4d4978b10bf8b9a0675ddbc2b596b7', 'batch_#': 2, 'article_#_in_batch': 9, 'headline': 'Strange new phase of matter created in quantum computer acts like it has two time dimensions'}
# {'article_id': 'dde2299e9e6a60a19468fbe2d0e775933b508048fad36c3725344325ac46ca92', 'batch_#': 2, 'article_#_in_batch': 10, 'headline': 'Physicists Confirm The Existence of Time Crystals in Epic Quantum Computer Simulation'}
# {'article_id': '1998b1f0c32c239632a281c3d27669f7849b0007e68f89f04147b97a36a65935', 'batch_#': 2, 'article_#_in_batch': 11, 'headline': 'Samsung develops method for self-emissive QLED'}
# {'article_id': '8ea4ba8801656b269bdf90c2078fe047e24bdf4227e9b4b14e1adc429d473f98', 'batch_#': 2, 'article_#_in_batch': 12, 'headline': "'Quantum time flip' makes light move simultaneously forward and backward in time"}
# {'article_id': '06399c5b4ab1a5472f8b503f64dcdd4c780bf8a06c73629571dafe49243a694d', 'batch_#': 2, 'article_#_in_batch': 13, 'headline': 'Experiment confirms quantum theory weirdness'}
# {'article_id': '605ce34a40a6581b6c88c335e82be5e7224586812afd8e6ee7ce0baafc1b526e', 'batch_#': 2, 'article_#_in_batch': 14, 'headline': "Otherworldly 'time crystal' made inside Google quantum computer could change physics forever"}
# {'article_id': '3b7cd20193006db9bbc577ed5875bb525338879b42c76c5c12b244387a5810dd', 'batch_#': 2, 'article_#_in_batch': 15, 'headline': 'IBM just proved quantum computers can do things impossible for classical ones '}
# {'article_id': '23d1b95ff5161dbca8f3c204f2106f97b83776ed28c3b2cb0f2af33544c80308', 'batch_#': 2, 'article_#_in_batch': 16, 'headline': 'IBM unveils its 433 qubit Osprey quantum computer'}
# {'article_id': 'e2f143a30e6988bcdfc8859ddf43e5e186b9ba4e019134be8a3be968f49baf88', 'batch_#': 2, 'article_#_in_batch': 17, 'headline': 'Trump signs legislation to boost quantum computing research with $1.2 billion'}
# {'article_id': '117685caa073514fe73c350dabff4803f174fc7a2824050dfa35006b5dbc738a', 'batch_#': 2, 'article_#_in_batch': 18, 'headline': 'Your brain might be a quantum computer that hallucinates math'}
# {'article_id': 'f0e9921caa2f1a19dbcfb6fb57e5fd0d65ac37610d394524b7cced8ca750dbeb', 'batch_#': 2, 'article_#_in_batch': 19, 'headline': 'Ancient Namibian stone holds key to future quantum computers | University of St Andrews news'}
# {'article_id': '04d0b5f99f47b05b52e2bc1a76cb676dac025415f29e096a0ab31d3eb279d1d0', 'batch_#': 2, 'article_#_in_batch': 20, 'headline': 'Researchers teleport information within a diamond'}
# {'article_id': 'ef43f8883015ee218167361e633f8079b5cd9ee16f0d0f3b43a69d364c82cf5f', 'batch_#': 3, 'article_#_in_batch': 1, 'headline': 'Scientists Report Finding Reliable Way to Teleport Data'}
# {'article_id': '0dd45a56bdab6a6e4e45f49580dce6a1132ca5112ec93e557ecb479247e8b11e', 'batch_#': 3, 'article_#_in_batch': 2, 'headline': 'Trapping the Tiniest Sound'}
# {'article_id': '04e35243dba48f516aab2258ae8b4a0c138ffa820cb2b865adc59266909109a1', 'batch_#': 3, 'article_#_in_batch': 3, 'headline': "Oxford Physicist Unloads on Quantum Computing Industry, Says It's Basically a Hype Bubble"}
# {'article_id': 'e5e5913e209aa268744c836418e9d7fe9d771edb641ba253ae2ec8e7e00f80b7', 'batch_#': 3, 'article_#_in_batch': 4, 'headline': 'Quantum causal relations: A causes B causes A'}
# {'article_id': 'aaaaf2d45e8707f0312b069aef2fdad270d8ff400062152fa25e2bba9d6b1c8e', 'batch_#': 3, 'article_#_in_batch': 5, 'headline': 'Two Diamonds Linked by Strange Quantum Entanglement'}
# {'article_id': '90b2e04127e573538a9ed494b35a8632aa8b90bb676c66425dfe3c1f1ac289b5', 'batch_#': 3, 'article_#_in_batch': 6, 'headline': "Researchers create an 'un-hackable' quantum network over hundreds of kilometers using optical fiber"}
# {'article_id': '6cf1a48706f28308760b04053772040ba97f659d4952fad22dc478cc019ee4af', 'batch_#': 3, 'article_#_in_batch': 7, 'headline': 'Open-air quantum teleportation performed across a 97km lake'}
# {'article_id': 'fec93fbbb4ba66468152150231edd532fbde851a49940ce90ecaa692f460f34d', 'batch_#': 3, 'article_#_in_batch': 8, 'headline': "Quantum measurements leave Schrödinger's cat alive"}
# {'article_id': 'b1ccad944a7f32a07834d7b41ed7590ed6ce09067b5c2838c7073851423bc53a', 'batch_#': 3, 'article_#_in_batch': 9, 'headline': 'New research suggests our brains use quantum computation'}
# {'article_id': '62077eaa137927fb40efd79dc9a4cf05f576c2302224d6c0dfa4abaf9454f495', 'batch_#': 3, 'article_#_in_batch': 10, 'headline': "China launches 'unhackable', quantum-secured smartphone"}
# {'article_id': 'a950a8970ee56a73929725650036db031ca30585e56c600c84b28bf96f82ff81', 'batch_#': 3, 'article_#_in_batch': 11, 'headline': 'Ancient Namibian stone could hold key to future quantum computers'}
# {'article_id': '88770fb2890ab53c9458f6dcdb117605543d8574f331dbbd442bb23a8b60977b', 'batch_#': 3, 'article_#_in_batch': 12, 'headline': 'A Quantum Solution to an 18th-Century Puzzle'}
# {'article_id': '1ffa4c02919bc8849f4df1fe7d2369a0bc2c2bc7c15049fe8aef672884223c63', 'batch_#': 3, 'article_#_in_batch': 13, 'headline': 'Toshiba has invented a quantum cryptography network that even the NSA can’t hack'}
# {'article_id': '41fe5477fb1215e2fe84fc6052c9b38fea7b9fe4b9c55595eadf5d47f91222df', 'batch_#': 3, 'article_#_in_batch': 14, 'headline': 'AI Designs Quantum Physics Experiments beyond What Any Human Has Conceived'}
# {'article_id': '3cba1b966b04bb45a0c163044a414adcf5ab2c9cbb30d316a22190b52f8ba620', 'batch_#': 3, 'article_#_in_batch': 15, 'headline': 'US blacklists Chinese quantum computing firms over security fears'}
# {'article_id': '8ebd01e59b98b1bf0448b2f1f5c4eb38e86a5e733ed711cf48a46649b46ef932', 'batch_#': 3, 'article_#_in_batch': 16, 'headline': 'New Study Fuels Debate About Source of Birds’ Magnetic Sense'}
# {'article_id': '95d91646c8913e57cb2f706ccb3fab13ae55d0082016db15c9441b32c5ac9182', 'batch_#': 3, 'article_#_in_batch': 17, 'headline': 'IBM unveils first quantum computer in Germany – DW – 06/15/2021'}
# {'article_id': '29aacf90c0bb542751556541980cb921498d68d374feef5848a2daeb0a80421c', 'batch_#': 3, 'article_#_in_batch': 18, 'headline': 'The Philosophy of Guessing Has Harmed Physics, Expert Says'}
# {'article_id': 'cae580937865123e8e287977338a31aa6aa241b06d8497604195ac6a2d542e73', 'batch_#': 3, 'article_#_in_batch': 19, 'headline': "Google reportedly attains 'quantum supremacy'"}
# {'article_id': '0bd49370ee2c42be2cd8441bac2013ba14781aee228ddf96894bcd9a41ee6a88', 'batch_#': 3, 'article_#_in_batch': 20, 'headline': 'Google Unveils 72-Qubit Quantum Computer With Low Error Rates'}
# {'article_id': '9b2f68aa0a4f075ec52bff19436a0f5b5041f73aa00c60a1020010bf60359fdf', 'batch_#': 4, 'article_#_in_batch': 1, 'headline': 'Physicists Just Quantum Teleported Information Between Particles of Matter'}
# {'article_id': '65d178ab1755fe72794383d2a04084c8a9dffa268212d16832a8c08120c6920d', 'batch_#': 4, 'article_#_in_batch': 2, 'headline': 'Physicists Say Aliens May Be Using Black Holes as Quantum Computers'}
# {'article_id': 'f03e79be4c968095d5f1e3b63bc4c9dc2df54259df93de0a4963728af4193288', 'batch_#': 4, 'article_#_in_batch': 3, 'headline': 'In a Quantum Future, Which Starship Destroys The Other?'}
# {'article_id': 'c7c3ba82a7b0f2f913cac7ec1f9a7a4ac50b6af0e462f4e31990aed2c694c775', 'batch_#': 4, 'article_#_in_batch': 4, 'headline': 'This Glowing Crystal Has the Quantum Internet Within Reach'}
# {'article_id': '279bd7d9482f5c5cb0b48da7f10a0acbfb0ca1ca6b39d7bed849fa9e1ca3f764', 'batch_#': 4, 'article_#_in_batch': 5, 'headline': 'Big Bang theory under threat from quantum graphity breakthrough'}
# {'article_id': '0e2c511268f9d5f0e1d3449da52a048a8fdc7b62e2dde7f005e91eba5787d508', 'batch_#': 4, 'article_#_in_batch': 6, 'headline': 'Quantum tunneling in graphene advances the age of terahertz wireless communications'}
# {'article_id': '0b2c7fbc152b3e9d3a52714b4970912f238562d485080f628032be3c76266761', 'batch_#': 4, 'article_#_in_batch': 7, 'headline': 'Study Confirms: Global Quantum Internet Really Is Possible'}
# {'article_id': '4af6c1fcd8ea04e11b61d9dd9949aee2f906c9839a9df57651fe4ee255d77f75', 'batch_#': 4, 'article_#_in_batch': 8, 'headline': "Scientists announce major breakthrough in 'quantum teleportation'"}
# {'article_id': '0deea3506c00dd4a4d67a8411123c2d0e7053620ef64df1a5cf01e3d6272b5d0', 'batch_#': 4, 'article_#_in_batch': 9, 'headline': 'Scientists discover way to make quantum states last 10,000 times longer'}
# {'article_id': 'c6fa1f05a17773064ca90289cfc5153caa0e4780b78cea5593e2548b3ff70026', 'batch_#': 4, 'article_#_in_batch': 10, 'headline': 'Quantum Chip Takes Microseconds to Do a Task a Supercomputer Would Spend 9,000 Years On'}
# {'article_id': '67f791878bd165e3943cf9c59e5af0548d1214f319f2d923e140a7edbe651450', 'batch_#': 4, 'article_#_in_batch': 11, 'headline': 'A quantum computer just solved a decades-old problem three million times faster than a classical computer'}
# {'article_id': 'c92b11e5facbe9bd5c90b702b5a9e1d1e8d0d8d8a4d0c7b85729bd2b559a210f', 'batch_#': 4, 'article_#_in_batch': 12, 'headline': 'Antimatter acts like regular matter in classic double-slit experiment'}
# {'article_id': '2be0d8fe7e5daa86ffb1b15af7319940e649bf382eede35623ee5b04f9068395', 'batch_#': 4, 'article_#_in_batch': 13, 'headline': 'Free Open-Access Quantum Computer Now Operational'}
# {'article_id': 'bde786e25c05f23816451f432f9a0e634997366b567e201ae9efcb6c036a367c', 'batch_#': 4, 'article_#_in_batch': 14, 'headline': 'Government Lab Reveals It Has Operated Quantum Internet for Over Two Years'}
# {'article_id': '0bcc1e323e41ebf61d76b7695132dabca1a6089eaf7aeb17cdbb937a6c547c49', 'batch_#': 4, 'article_#_in_batch': 15, 'headline': 'The case against dark matter'}
# {'article_id': '198e2416cf4bae6d79ecf481c6468a7871e786996523c95324b8549d611ae84f', 'batch_#': 4, 'article_#_in_batch': 16, 'headline': 'UK military wants to install quantum computers in tanks'}
# {'article_id': '3160a1832a29ffc7580ad55a00f2f6dd94c03fba90beb4306afb822112f18a12', 'batch_#': 4, 'article_#_in_batch': 17, 'headline': 'Quantum computers may be for sale sooner than you think. And Canadian firms are at the forefront | CBC News'}
# {'article_id': 'f19ad34e670bf695d067d5213d8ce141090285a119f44585635a973c8fbd32dc', 'batch_#': 4, 'article_#_in_batch': 18, 'headline': 'Quantum internet closer as physicists stretch spooky link between atoms'}
# {'article_id': 'c21ef5cec094b63c1f442501cbce6fc262e8445ee93c4353c9626b48fda1bcf3', 'batch_#': 4, 'article_#_in_batch': 19, 'headline': 'Hot qubits made in Sydney break one of the biggest constraints to practical quantum computers'}
# {'article_id': 'bb6823749eb0cf27b1606d33ffc5f79153d89c8199956820434bcc892059849e', 'batch_#': 4, 'article_#_in_batch': 20, 'headline': 'First quantum jiggles detected in solid object'}
# {'article_id': '242c303d2ef7dccd3f1572bc5c8d89c1c1793e38a0330dbf421555089c5a06a9', 'batch_#': 5, 'article_#_in_batch': 1, 'headline': '“Schrödinger’s Bacterium” Could Be a Quantum Biology Milestone'}
# {'article_id': '09c00dfab63ed58c4b3fb2027d11b33257a221cfe256ab78f73108b60375f009', 'batch_#': 5, 'article_#_in_batch': 2, 'headline': 'New invention keeps qubits of light stable at room temperature'}
# {'article_id': '7bc6583ee6d886ef9791bce115655421aacee2e4ec545f0e1919235c636699b8', 'batch_#': 5, 'article_#_in_batch': 3, 'headline': 'Researchers achieve first "sustained" long distance quantum teleportation'}
# {'article_id': 'd752eba1fa418dcb19b61b11069aa6250c40d25edf05b99989d793a3f5851db7', 'batch_#': 5, 'article_#_in_batch': 4, 'headline': 'IBM will sell 50-qubit universal quantum computer “in the next few years”'}
# {'article_id': '4a3596cd115a7baec320f82180c6385ad1e99fb79d1f7766c16fd2d4192bc170', 'batch_#': 5, 'article_#_in_batch': 5, 'headline': "NSA doesn't think quantum computers can break public key encryption"}
# {'article_id': '53fbb2ed27c346d32dbc9f483eb6066c0db3b04368b7f24454135a1c02c036b1', 'batch_#': 5, 'article_#_in_batch': 6, 'headline': 'Quantum gravity takes singularity out of black holes'}
# {'article_id': '77ec19395c3d2e413ba3d746532ba5c85c25ca2a9f12a19c7e2bbef47f0bb09d', 'batch_#': 5, 'article_#_in_batch': 7, 'headline': 'Scientists take huge step towards revolutionary ‘quantum internet’'}
# {'article_id': '9738f872ed91cf0c477816858b210ee18477185564a813034c25685b2dd51d7a', 'batch_#': 5, 'article_#_in_batch': 8, 'headline': 'Photons detected without being destroyed'}
# {'article_id': '2e61a3b5db1353cdfe631e5d3503b0d15195aded0b1317486e81220121a3b43c', 'batch_#': 5, 'article_#_in_batch': 9, 'headline': "In the Blink of Bird's Eye, a Model for Quantum Navigation"}
# {'article_id': 'f46c396edc7a3ded7d1932c53ab7497da08b2389dfa4186760135a0031b051a2', 'batch_#': 5, 'article_#_in_batch': 10, 'headline': 'Aliens could send quantum messages to Earth, calculations suggest'}
# {'article_id': '7e5fb72a17c7e3c531ad507d3dcd5bd099269d1974d6535fb417fd023ae8d95d', 'batch_#': 5, 'article_#_in_batch': 11, 'headline': 'New qubit control bodes well for future of quantum computing'}
# {'article_id': 'df5416072c5502fcd179e7bbd9d59634a2c264451b25fe13950f576dac0663db', 'batch_#': 5, 'article_#_in_batch': 12, 'headline': 'Amazon is opening a center for quantum networking research | Engadget'}
# {'article_id': '3a6b62ee4038bc1caf0f1c89fbe182f03c80a3eebf93bac19a30cc56911cf07c', 'batch_#': 5, 'article_#_in_batch': 13, 'headline': 'Bizarre new quantum research: Reality itself may be subjective'}
# {'article_id': 'ca035181d7befd6377ea18af295049b6a3bd483c6f94d35b8cce070c078fa65b', 'batch_#': 5, 'article_#_in_batch': 14, 'headline': 'Engineers crack 58-year-old puzzle on way to quantum breakthrough'}
# {'article_id': '986a55784c03dcdb71c5897432551c692e182caa7e21577e732794bbe0f05cff', 'batch_#': 5, 'article_#_in_batch': 15, 'headline': 'New Quantum Technology To Make Charging Electric Cars As Fast as Pumping Gas'}
# {'article_id': '71b37250c7f3bb15759597474e927385f2aff6ac610a14792688bfdc4e575a4d', 'batch_#': 5, 'article_#_in_batch': 16, 'headline': 'Ultra-weak gravitational field detected'}
# {'article_id': 'd12a09ea3ce255785c7308048b93287235713b3e2af06b771f4654c3ded96d18', 'batch_#': 5, 'article_#_in_batch': 17, 'headline': 'New AMD Patent Proposes Teleportation to Make Quantum Computing More Efficient'}
# {'article_id': 'ca2e2ee5d2e3091569a9caa499f6cde9cb0477e40ca948d080720dcc0d2a88f4', 'batch_#': 5, 'article_#_in_batch': 18, 'headline': 'Chicago expands and activates quantum network, taking steps toward a secure quantum internet'}
# {'article_id': '76ce4cf476b0fba2feaa2e284274ce84f156b133ab4126cb9041b5e2c3ad8570', 'batch_#': 5, 'article_#_in_batch': 19, 'headline': 'SU(N) matter is about 3 billion times colder than deep space'}
# {'article_id': 'fa45bb4e5a1ff9353de43555f3a9f9aa1030de53a192ce93011d289820241189', 'batch_#': 5, 'article_#_in_batch': 20, 'headline': 'Dwave has a 1000 qubit quantum computer now in their lab and will release in later in 2014 | NextBigFuture.com'}
# {'article_id': 'af95ecc5118a0e8112771a7d2f01227bcc3156db9a19e968cabbdfd67e161e4a', 'batch_#': 6, 'article_#_in_batch': 1, 'headline': 'You thought quantum mechanics was weird: check out entangled time | Aeon Ideas'}
# {'article_id': '398adceecc3273c80dba6f25ad70c4e04e3d30a6ad4ea037b18cbba24e0389f6', 'batch_#': 6, 'article_#_in_batch': 2, 'headline': 'Metro Vancouver firm’s groundbreaking quantum computer wins confidence of U.S. aerospace giant '}
# {'article_id': '76c971eff2c22979a55cadcf6f5a6edc1b069381f6a93485305cef48831b5c07', 'batch_#': 6, 'article_#_in_batch': 3, 'headline': '‘Urgent’ Warning Issued Over The Future Of Bitcoin Even As The Crypto Market Price Smashes Past $2 Trillion'}
# {'article_id': '37a4407d48b3a5537fc5de3cba040359104312f2235a41525e31e3fbdf7ccfd9', 'batch_#': 6, 'article_#_in_batch': 4, 'headline': 'Eco-Friendly Nanoparticles for Artificial Photosynthesis'}
# {'article_id': 'b8954375d63dbe9af7aeee42a446e2da4686483a14ba9dda5640a07ac5af4bd7', 'batch_#': 6, 'article_#_in_batch': 5, 'headline': 'Microsoft Says Its Had a Breakthrough in Quantum Computer System'}
# {'article_id': '105be516af6ed91a2be61dedadc92fa90235680ccc4e00fa3276d836f586e6e1', 'batch_#': 6, 'article_#_in_batch': 6, 'headline': 'Scientists calculate absolute quantum speed limit for electronics'}
# {'article_id': 'e268a3100bd2bf15c77f5fee34c7de4e01bd14033c0e282dfdcdd216a42422c0', 'batch_#': 6, 'article_#_in_batch': 7, 'headline': 'Quantum microphone counts particles of sound | Stanford News'}
# {'article_id': '4b865ce095268498e64a8f5d11ab8f2586a4f0e058562604901680fe68dd26bb', 'batch_#': 6, 'article_#_in_batch': 8, 'headline': 'Quantum hackers can bring down Bitcoin: expert'}
# {'article_id': '0a36598418fef43301f9a364903b8e2523d34619b10c28b23f506fb457455fdb', 'batch_#': 6, 'article_#_in_batch': 9, 'headline': 'NIST Quantum Refrigerator Offers Extreme Cooling and Convenience'}
# {'article_id': '626eb66fedcae59f9278664c99144098f07bfe149757f1e9e6683d4e31946b95', 'batch_#': 6, 'article_#_in_batch': 10, 'headline': 'Major Quantum Computing Advance Made Obsolete by Teenager | Quanta Magazine'}
# {'article_id': '4662805110723ef2a6bf57a1262de8bbf345f33e5aee808e35a44c96d582b24c', 'batch_#': 6, 'article_#_in_batch': 11, 'headline': 'Harvard-MIT Quantum Computing Breakthrough – “We Are Entering a Completely New Part of the Quantum World”'}
# {'article_id': '95fa0265697a7f0067a3c0ccc3ccf6713b830925f180c22b09e29b5f4c1eb463', 'batch_#': 6, 'article_#_in_batch': 12, 'headline': 'Quantum Teleportation Enters the Real World'}
# {'article_id': '0ba5397aa7e55a3599693501b77e8f8658d0306f88bc26e4433655ecb2e9896e', 'batch_#': 6, 'article_#_in_batch': 13, 'headline': 'Large-scale quantum chip validated'}
# {'article_id': '74435a27b9cd11244137c122407b177cbfa1fd2d26a7ecb9c8c798a89b802f56', 'batch_#': 6, 'article_#_in_batch': 14, 'headline': 'Nasa scientists achieve long-distance quantum teleportation that could pave way for quantum internet'}
# {'article_id': '1a86bf3d473f8bb8a5f6bf4363326801c29b71c762ccd8df2b6c67c93872d8df', 'batch_#': 6, 'article_#_in_batch': 15, 'headline': 'Flipping the switch'}
# {'article_id': '29c78ffc62beebcc4df8e6c87f47a58bee0cc4d6183ba50c883baecba6bc320d', 'batch_#': 6, 'article_#_in_batch': 16, 'headline': 'Harvard-led physicists create 256-qubit programmable quantum simulator'}
# {'article_id': 'eaaffba4c5f53b9a0962c45494864cde9445a0e328778180f8d0e1238fc94f76', 'batch_#': 6, 'article_#_in_batch': 17, 'headline': 'Mathematical calculations show that quantum communication across interstellar space should be possible'}
# {'article_id': '28dc4cea2e5191b861553243d4fc662a282c4e7db068ca311a33f044e0d08df6', 'batch_#': 6, 'article_#_in_batch': 18, 'headline': 'Google’s Quantum Dream Machine'}
# {'article_id': '67c47b25edf1d5f068270aa4c1d18b0a8258c7ecc2d6e2cb3f5deb2014488300', 'batch_#': 6, 'article_#_in_batch': 19, 'headline': 'Artificial intelligence reduces a 100,000-equation quantum physics problem to only four equations'}
# {'article_id': 'ec6950e4738a52f153382ef5921a5a769042fdbd47c85d9fcf242ea396ced227', 'batch_#': 6, 'article_#_in_batch': 20, 'headline': 'Fluxonium qubits bring the creation of a quantum computer closer'}
# {'article_id': '42ab40eb67912bbf9099d0fb97d2cb0d211f13f94a4dc55c887174832b65a481', 'batch_#': 7, 'article_#_in_batch': 1, 'headline': 'Quantum Random Number Generator Created Using A Smartphone Camera'}
# {'article_id': '6763d5878b0ccdf4ed74af92684bdc0977ecaf9627da4bd6f73de0ef59e172a4', 'batch_#': 7, 'article_#_in_batch': 2, 'headline': 'Cyber Insights 2023 | Quantum Computing and the Coming Cryptopocalypse'}
# {'article_id': 'aadb1f281f6e55b296321264cc37677a39e867259d257e3a4c75a99fc9e2e4a4', 'batch_#': 7, 'article_#_in_batch': 3, 'headline': 'New quantum paradox reveals contradiction between widely-held beliefs'}
# 123

# %%
instance_labels = ["A", "B", "C", "D", "E", "F", "G", "H"]
def export_annotation_data(art_info_batched_collection, responses, filename="headline_annotation_data.csv", check_sample_arts=None):
    """Exports annotation data to csv file.
        Note that check_sample_cmts is a list of tuples (batch, comment in batch).
    """	
    
    
    art_data_buffer = []
    
    for b_i in range(len(art_info_batched_collection)): #Iterate over batches
        
        batch_annotated_by = responses[b_i]["annotated_by"]
        
        for art_labels, art_info in zip(responses[b_i]["labels"], art_info_batched_collection[b_i]): #Iterate over articles in batch
            
            art_data = {"article_id": art_info["article_id"],
                        "batch_#": cmt_info["batch_#"],
                        "article_#_in_batch": art_info["article_#_in_batch"],
                        "headline": art_info["headline"],
                        }
            
            if check_sample_arts is not None:
                if (b_i, art_info["comment_#_in_batch"]) in check_sample_arts:
                    art_data["selected_for_check"] = 1
                else:
                    art_data["selected_for_check"] = 0
            
            for annot_feat in ["sentiment"]:
                for rep_i, inst_label in enumerate(instance_labels):
                    art_data[annot_feat + "_GPT4_" + str(inst_label)] = art_labels[annot_feat][rep_i]

            art_data_buffer.append(art_data)

    annotation_data = pd.DataFrame(art_data_buffer)
    
    assert filename.endswith(".csv")
    export_filepath = "./"+filename  
    annotation_data.to_csv(export_filepath, index=False, sep= ";", header=True)
    return annotation_data


def post_retrieval_annotation_parsing(raw_response_strings, annotation_classes, annotation_batch_size, art_info_batched_collection):
    responses = []
    
    for b_i, art_info_batch in enumerate(art_info_batched_collection): #Iterate batches
        
        batch_annotations = []
        
        #Recall that chat_prompts contains two items: "article_ids" and "messages" of a single batch
        num_articles_in_batch = annotation_batch_size
        batch_article_indices = list(range(num_articles_in_batch))
        
        for art_i in batch_article_indices: #Prepare a storage for the annotations of each headline in the batch
            print("Article {} of batch {}".format(art_i+1, b_i+1))
            art_annotations = {}
            art_annotations["article_idx_in_batch"] = art_i+1
            art_annotations["article_id"]= cmt_info_batch[art_i]["article_id"]
            batch_annotations.append(art_annotations)
        
        for feat_i, annot_feat in enumerate(annotation_classes.keys()): #Request annotationsm, parse them and save them in the batch_annotations
            response_contents = raw_response_strings[2*b_i+feat_i]
            assert type(response_contents) == list

            # Convert response to raw annotations:
            try: #If response contents can't be parsed into annotations, skip this batch
                # Convert response to raw annotations:
                for art_i in batch_article_indices:
                    print(art_i)
                    batch_annotations[art_i][annot_feat] = [ ]
                    for rc in response_contents:
                        print(rc)
                        rc = rc.strip()
                        temp_annot_str = rc.split("<#{}#>".format(art_i+1))[1]
                        art_annotation_str = temp_annot_str.split(";")[0]
                        #batch_annotations[cmt_i][annot_feat].append(cmt_annotation_str.lower())
                        for annot_class in annotation_classes[annot_feat]:
                            if annot_class in art_annotation_str.lower():
                                batch_annotations[art_i][annot_feat].append(annot_class)
                                break #Only one annotation per class is allowed
            except:
                print("Response couldn't be parsed! Skipping batch {}...".format( b_i+1))
                print(response_contents)
                raise Exception("Response couldn't be parsed!")
        
        responses.extend([{"batch_id": b_i, "annotated_by": "GPT-4", "labels": batch_annotations}])

    return responses

# %%
export_df = export_annotation_data(art_info_batched_collection, 
                                   responses, 
                                   filename="full_headline_withcrit_hightemp_annotation_data.csv", 
                                   check_sample_arts=None
                                   )
